# %% [markdown]
# # <a id="TOC"> Start </a>

# %%
import backtesting # To backtest the strategy
import heuristic_pf_construct # To test out the weighted strategies.
import eda_pipeline

from typing import Optional, List, Tuple, Dict
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import backtesting # To backtest the strategy
#       2 import heuristic_pf_construct # To test out the weighted strategies.
#       3 import eda_pipeline
#
# ModuleNotFoundError: No module named 'backtesting'

# %%
tickers = [
    "JPM",   # JPMorgan (NYSE)
    "GS",    # Goldman Sachs (NYSE)
    "MS",    # Morgan Stanley (NYSE)
    "BAC",   # Bank of America (NYSE)
    "C",     # Citigroup (NYSE)
    "UBS",   # UBS (NYSE / SIX)
    "BARC.L",# Barclays (LSE)
    "HSBA.L",# HSBC (LSE)
    "BNP.PA" # BNP Paribas (Euronext Paris)
]

columns_wanted = ["Open", "High", "Low", "Close", "Adj Close", "Volume"]

data = yf.download(
    tickers=tickers,
    period="3y",          # or use start="2022-01-01", end="2025-11-26"
    interval="1d",
    group_by="ticker",    # organizes returned DataFrame by ticker first
    threads=True,
    auto_adjust=False     # keep Adj Close column rather than auto-adjusting all columns
)

# --- 4) Example: extract only needed columns into a MultiIndex DataFrame ---
# data[ticker][col] access pattern; create a cleaned df with tickers on top-level columns
clean = data.copy()
clean.columns = [f"{column}" for column in data.columns]
# now clean is a DataFrame with columns like ('JPM','Open'), ('JPM','Close'), ...

# --- 5) Quick derived metrics examples ---
# 5  using Adj Close
adj = pd.concat({t: data[t]["Adj Close"] for t in tickers}, axis=1)



# 5b) for daily returns
daily_returns = adj.pct_change().dropna()
# Out:
# [*********************100%***********************]  9 of 9 completed
# C:\Users\trund\AppData\Local\Temp\ipykernel_16960\50166549.py:37: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = adj.pct_change().dropna()

# %%
eda_pipeline.missing_and_duplicates(adj)
# Out:
# Total rows: 776, Duplicated rows: 0
#
# Top missing columns:
#         missing_count  missing_percentage
# JPM                24              3.0928
# GS                 24              3.0928
# MS                 24              3.0928
# BAC                24              3.0928
# C                  24              3.0928
# UBS                24              3.0928
# BARC.L             18              2.3196
# HSBA.L             17              2.1907
# BNP.PA              8              1.0309

# %%
adj[adj.isna().any(axis=1)]
# Out:
#                    JPM          GS          MS        BAC           C  \
# Date
# 2022-12-27  122.353065  317.152679   76.857475  30.224682   39.802971
# 2023-01-02         NaN         NaN         NaN        NaN         NaN
# 2023-01-16         NaN         NaN         NaN        NaN         NaN
# 2023-02-20         NaN         NaN         NaN        NaN         NaN
# 2023-04-10  120.593811  303.534973   76.511887  26.128342   42.124275
# 2023-05-01  133.144470  318.115784   80.785187  27.157015   43.254353
# 2023-05-08  129.250107  304.982819   77.569580  25.894548   42.439610
# 2023-05-29         NaN         NaN         NaN        NaN         NaN
# 2023-06-19         NaN         NaN         NaN        NaN         NaN
# 2023-07-04         NaN         NaN         NaN        NaN         NaN
# 2023-08-28  140.097183  306.796753   78.240669  27.109785   38.264690
# 2023-09-04         NaN         NaN         NaN        NaN         NaN
# 2023-11-23         NaN         NaN         NaN        NaN         NaN
# 2023-12-26  161.053391  365.132782   87.137230  32.439995   48.161083
# 2024-01-15         NaN         NaN         NaN        NaN         NaN
# 2024-02-19         NaN         NaN         NaN        NaN         NaN
# 2024-04-01  191.445648  398.459229   88.644783  36.199718   60.098801
# 2024-05-01  185.709335  411.410065   87.560478  35.649776   58.100563
# 2024-05-06  185.844864  427.521484   90.669197  36.363735   59.999969
# 2024-05-27         NaN         NaN         NaN        NaN         NaN
# 2024-06-19         NaN         NaN         NaN        NaN         NaN
# 2024-07-04         NaN         NaN         NaN        NaN         NaN
# 2024-08-26  213.319336  492.346375   98.761856  38.749516   59.593548
# 2024-09-02         NaN         NaN         NaN        NaN         NaN
# 2024-11-28         NaN         NaN         NaN        NaN         NaN
# 2024-12-26  238.099670  569.605347  124.542664  43.767818   69.423943
# 2025-01-09         NaN         NaN         NaN        NaN         NaN
# 2025-01-20         NaN         NaN         NaN        NaN         NaN
# 2025-02-17         NaN         NaN         NaN        NaN         NaN
# 2025-04-21  226.789505  493.769135  104.092613  36.500679   61.420105
# 2025-05-01  244.517502  545.444763  115.252785  39.713764   66.759705
# 2025-05-05  250.133011  551.088013  118.056114  40.652977   69.367470
# 2025-05-26         NaN         NaN         NaN        NaN         NaN
# 2025-06-19         NaN         NaN         NaN        NaN         NaN
# 2025-07-04         NaN         NaN         NaN        NaN         NaN
# 2025-08-25  293.473206  731.231079  146.756561  49.206303   94.436928
# 2025-09-01         NaN         NaN         NaN        NaN         NaN
# 2025-10-27  304.149994  786.092896  165.015411  53.020000  100.391418
# 2025-11-27         NaN         NaN         NaN        NaN         NaN
# 2025-12-04         NaN         NaN         NaN        NaN         NaN
#
#                   UBS      BARC.L       HSBA.L     BNP.PA
# Date
# 2022-12-27  17.140705         NaN          NaN  42.974621
# 2023-01-02        NaN         NaN          NaN  43.714737
# 2023-01-16        NaN  182.285553   594.791626  47.399410
# 2023-02-20        NaN  175.673355   619.337646  52.126617
# 2023-04-10  19.035009         NaN          NaN        NaN
# 2023-05-01  18.911892         NaN          NaN        NaN
# 2023-05-08  18.553280         NaN          NaN  46.388714
# 2023-05-29        NaN         NaN          NaN  47.757893
# 2023-06-19        NaN  153.324036   613.908997  48.362320
# 2023-07-04        NaN  152.424835   623.591858  49.281719
# 2023-08-28  23.526619         NaN          NaN  50.652313
# 2023-09-04        NaN  150.693726   584.834106  50.601234
# 2023-11-23        NaN  140.141174   610.771362  48.438938
# 2023-12-26  29.292667         NaN          NaN        NaN
# 2024-01-15        NaN  144.877823   595.494751  52.031414
# 2024-02-19        NaN  148.894989   637.231201  46.625668
# 2024-04-01  28.764193         NaN          NaN        NaN
# 2024-05-01  25.363909  203.370422   696.723816        NaN
# 2024-05-06  26.729435         NaN          NaN  58.084160
# 2024-05-27        NaN         NaN          NaN  60.933018
# 2024-06-19        NaN  206.619156   692.462708  53.345921
# 2024-07-04        NaN  224.262268   690.763977  58.079906
# 2024-08-26  30.138407         NaN          NaN  55.835583
# 2024-09-02        NaN  227.090881   665.461487  56.726044
# 2024-11-28        NaN  265.031036   731.497009  51.010731
# 2024-12-26  29.673546         NaN          NaN        NaN
# 2025-01-09        NaN  265.780823   802.058105  54.472630
# 2025-01-20        NaN  291.774048   824.845520  57.198532
# 2025-02-17        NaN  304.320770   880.814697  63.449940
# 2025-04-21  27.610001         NaN          NaN        NaN
# 2025-05-01  30.139999  294.775757   824.488525        NaN
# 2025-05-05  30.770000         NaN          NaN  69.383316
# 2025-05-26        NaN         NaN          NaN  74.669960
# 2025-06-19        NaN  319.723724   864.253845  72.175156
# 2025-07-04        NaN  330.472839   885.750183  72.407234
# 2025-08-25  40.189999         NaN          NaN  77.773956
# 2025-09-01        NaN  367.299988   953.512146  74.505577
# 2025-10-27  38.599998         NaN  1003.907532  69.190002
# 2025-11-27        NaN  429.950012  1065.000000  73.389999
# 2025-12-04        NaN  438.043610  1072.199585  75.129997

# %% [markdown]
# Based on the analysis above - we can identify that the missing values are caused by markets closing due to holidays on those days. The preceding analysis opts for a forward fill to deal with thees values.
#
# The next analysis requires us to check that there are no stupid values like 0 or negative values.

# %%
adj = adj.ffill(inplace=False)
adj[(adj <= 0).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [JPM, GS, MS, BAC, C, UBS, BARC.L, HSBA.L, BNP.PA]
# Index: []

# %% [markdown]
# # <a id="BNP TSA"> __BNP TSA__ </a>
# In this next section - we want to perform some analysis on the time-series behaviour of BNP.

# %%
import eda_pipeline

target = "BNP.PA"

df = eda_pipeline.eda_pipeline(adj)

# Want to do some TSA on the returns of target
target_series = df[[target]]

plt.figure(figsize=(10,3))
target_series.plot()
plt.show()

# %% [markdown]
# A clear trend is observed - we can try differencing the data and obtaining a stationary time series.

# %%
# Want to try differencing the df

target_returns= target_series.diff()
target_returns.dropna(inplace=True)
figsize = (15,4)
fig, ax = plt.subplots(figsize=figsize)

target_returns.plot(ax=ax)
plt.tight_layout()
plt.show()

# %% [markdown]
# From the returns plot we see that the series exhibits a bit of heteroskedacity, but looks stationary. We can proceed with the ACF and PACF plots.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

figsize = (15,10)
lags= 60
fig, ax = plt.subplots(nrows=2, figsize=figsize, sharex=True)
plot_acf(target_returns, ax=ax[0], lags=lags)
plot_pacf(target_returns, ax=ax[1], lags=lags)
plt.tight_layout()
plt.show()

# %% [markdown]
# From the ACF plots and PACF plots there seem to be no significant dependence on previous factors. Something appropriate instantly might be to do the Ljung-Box test on the data:

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox

ljb_test = acorr_ljungbox(target_returns, lags=20)
fig, ax = plt.subplots(figsize=(15,5))
ljb_test["lb_pvalue"].plot(ax=ax)
ax.set_title("LB Test for different lags")
ax.set_xticks(ljb_test.index)
ax.axhline(y=0.05, color="red", linestyle="--", label="0.05 significance level")
ax.legend()
plt.show()

# %% [markdown]
# From the Ljung Box Test it seems that none of the lags have a statistically significant effect on the current time-step. It seems further predictors must be added to capture a significant effect of the lag. However there is a clear trend in the data so it must be that the returns are dependent. We conclude that the differencing procedure is not appropriate for modelling.

# %%
sns.histplot(target_series, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# The returns still look skewed despite the log transformation. For the purposes of predicting returns easier it might be helpful to just keep the time-series in the regular differences.

# %% [markdown]
# # <a id="Create Strategy">__Strategy Creation__ </a>

# %%
import sys
sys.path.append(r"c:\\Users\\trund\\QRT")
import backtesting # To backtest the strategy
import heuristic_pf_construct # To test out the weighted strategies.
import eda_pipeline

from typing import Optional, List, Tuple, Dict
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# Recreation of the dataset we are trying to retrieve.
tickers = [
    "JPM",   # JPMorgan (NYSE)
    "GS",    # Goldman Sachs (NYSE)
    "MS",    # Morgan Stanley (NYSE)
    "BAC",   # Bank of America (NYSE)
    "C",     # Citigroup (NYSE)
    "UBS",   # UBS (NYSE / SIX)
    "BARC.L",# Barclays (LSE)
    "HSBA.L",# HSBC (LSE)
    "BNP.PA" # BNP Paribas (Euronext Paris)
]

columns_wanted = ["Open", "High", "Low", "Close", "Adj Close", "Volume"]

data = yf.download(
    tickers=tickers,
    period="3y",          # or use start="2022-01-01", end="2025-11-26"
    interval="1d",
    group_by="ticker",    # organizes returned DataFrame by ticker first
    threads=True,
    auto_adjust=False     # keep Adj Close column rather than auto-adjusting all columns
)

# --- 5) Quick derived metrics examples ---
# 5  using Adj Close
adj = pd.concat({t: data[t]["Adj Close"] for t in tickers}, axis=1)

adj = eda_pipeline.eda_pipeline(adj)
"""
Currently my implementation is spaghetti code - but we will need to fix this later.
"""

def equal_weighting(
    tradable_assets, 
    history, 
    nav_history, 
    #price_col: str = "price",
    #risk_col: str = "risk",
    #mcap_col: str = "mcap",            # unused but kept for identical signature
    #long_only: bool = True,
    gross_exposure: float = 1.0,
) -> pd.DataFrame:
    # With no amount in cash. 
    """
    Equal weighting. If long_only=True returns all weights = 1/N.
    If long_only=False returns centered long-short equal-magnitude weights (gross exposure scaled).
    """
    n = len(tradable_assets)
    if len(history) == 0:
        return 0, pd.Series(data=np.zeros(len(tradable_assets)), index=tradable_assets)
    #if long_only:
    weights = np.ones(n) / (n + 1)
    cash = 1 / n + 1
    #else:
        # initial pattern: +1 for first half, -1 for second half (user may want to pre-sort df by signal)
        #pattern = np.concatenate([np.ones(n // 2), -np.ones(n - n // 2)])
        #weights = _normalize_weights(pattern, long_only=False, gross_exposure=gross_exposure)

    labels_and_weights = pd.Series(data=weights, index=tradable_assets)
    return cash, labels_and_weights
# Out:
# [*********************100%***********************]  9 of 9 completed

# %%
# The first strategy we will start implementing is the equal weights strategy - this will be based on the weights of the previous trading day. 

EqualWeightStrategy = backtesting.FunctionStrategy(name="equal_weight", 
                                                   user_fn=heuristic_pf_construct.equal_weighting)

tradable_assets = [
    "JPM",   # JPMorgan (NYSE)
    "GS",    # Goldman Sachs (NYSE)
    "MS",    # Morgan Stanley (NYSE)
    "BAC",   # Bank of America (NYSE)
    "C",     # Citigroup (NYSE)
]

# Need to wrap the strategy function into a strategy to be compatible with the pipeline
strategy_name = "equal_weights"
equal_weights = equal_weighting


backtester = backtesting.Backtester(tradable_assets=tradable_assets,
                                    data = adj,
                                    strategy_fn=equal_weights,
                                    strategy_name=strategy_name,
                                    allow_short=False,
                                    cash_start=100000,
                                    riskfree_per_period=0.04 / 252)

backtester.run(verbose=True)
# Out:
# 2023-01-23: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    127.854027
# GS     323.802277
# MS      87.763527
# BAC     31.722980
# C       46.608658
# Name: 2023-01-23 00:00:00, dtype: float64
# JPM    130.356994
# GS      51.471740
# MS     189.904249
# BAC    525.381487
# C      357.587355
# dtype: float64
#
# 2023-01-24: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    128.953094
# GS     323.051117
# MS      86.299759
# BAC     31.954060
# C       46.106529
# Name: 2023-01-24 00:00:00, dtype: float64
# JPM   -1.410261
# GS     0.000239
# MS     2.773929
# BAC   -5.006909
# C      3.057451
# dtype: float64
#
# 2023-01-25: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    129.577087
# GS     324.256744
# MS      86.417213
# BAC     32.231361
# C       46.536938
# Name: 2023-01-25 00:00:00, dtype: float64
# JPM   -0.023277
# GS     0.047461
# MS     0.634304
# BAC   -2.074225
# C     -1.671337
# dtype: float64
#
# 2023-01-26: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.378143
# GS     329.209167
# MS      87.194283
# BAC     32.665791
# C       46.796963
# Name: 2023-01-26 00:00:00, dtype: float64
# JPM    0.265248
# GS    -0.356274
# MS    -0.141748
# BAC   -2.672744
# C      0.951246
# dtype: float64
#
# 2023-01-27: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.694824
# GS     328.031372
# MS      87.519577
# BAC     32.767467
# C       46.501064
# Name: 2023-01-27 00:00:00, dtype: float64
# JPM   -0.326529
# GS     0.178323
# MS    -0.738137
# BAC   -1.653821
# C      2.252359
# dtype: float64
#
# 2023-01-30: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    129.586441
# GS     331.518433
# MS      87.405724
# BAC     32.628815
# C       46.402428
# Name: 2023-01-30 00:00:00, dtype: float64
# JPM    0.982970
# GS    -0.586634
# MS     0.073908
# BAC    1.710598
# C      0.436934
# dtype: float64
#
# 2023-01-31: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.359512
# GS     339.262543
# MS      88.653595
# BAC     32.795200
# C       46.823868
# Name: 2023-01-31 00:00:00, dtype: float64
# JPM    0.473050
# GS    -0.680904
# MS    -0.881828
# BAC    2.324841
# C      0.197037
# dtype: float64
#
# 2023-02-01: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.014862
# GS     339.169708
# MS      89.436928
# BAC     33.201900
# C       46.761093
# Name: 2023-02-01 00:00:00, dtype: float64
# JPM    0.715210
# GS     0.155445
# MS    -1.140829
# BAC   -4.897332
# C      1.515128
# dtype: float64
#
# 2023-02-02: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    129.409485
# GS     342.656891
# MS      90.366005
# BAC     33.396011
# C       46.823868
# Name: 2023-02-02 00:00:00, dtype: float64
# JPM    1.122055
# GS    -0.318917
# MS    -1.229381
# BAC   -1.009721
# C      0.918538
# dtype: float64
#
# 2023-02-03: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    131.412003
# GS     343.102112
# MS      90.566391
# BAC     33.673313
# C       46.135670
# Name: 2023-02-03 00:00:00, dtype: float64
# JPM   -1.740616
# GS     0.039885
# MS    -0.022283
# BAC   -3.150894
# C      6.226560
# dtype: float64
#
# 2023-02-06: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.185028
# GS     343.890320
# MS      90.083649
# BAC     33.617851
# C       46.054184
# Name: 2023-02-06 00:00:00, dtype: float64
# JPM   -0.774856
# GS    -0.119171
# MS     0.996186
# BAC    0.791753
# C      0.622294
# dtype: float64
#
# 2023-02-07: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    133.796387
# GS     347.229156
# MS      90.375107
# BAC     33.987587
# C       46.298668
# Name: 2023-02-07 00:00:00, dtype: float64
# JPM   -0.676675
# GS    -0.138290
# MS     0.696169
# BAC   -2.062821
# C      0.591572
# dtype: float64
#
# 2023-02-08: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.855682
# GS     347.878326
# MS      90.138290
# BAC     33.738014
# C       46.316772
# Name: 2023-02-08 00:00:00, dtype: float64
# JPM    0.594217
# GS    -0.214530
# MS     0.031539
# BAC    2.499612
# C     -1.060490
# dtype: float64
#
# 2023-02-09: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.787949
# GS     341.284302
# MS      89.309418
# BAC     33.017033
# C       45.257332
# Name: 2023-02-09 00:00:00, dtype: float64
# JPM    0.118981
# GS     0.216630
# MS    -1.053090
# BAC    3.498228
# C      3.124026
# dtype: float64
#
# 2023-02-10: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    131.365417
# GS     344.335571
# MS      89.664635
# BAC     32.887630
# C       45.375053
# Name: 2023-02-10 00:00:00, dtype: float64
# JPM   -0.225435
# GS    -0.308894
# MS    -0.247444
# BAC    3.397655
# C      0.025428
# dtype: float64
#
# 2023-02-13: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.790451
# GS     346.876709
# MS      90.566391
# BAC     32.952339
# C       46.180954
# Name: 2023-02-13 00:00:00, dtype: float64
# JPM   -0.364422
# GS     0.030511
# MS    -0.385824
# BAC    3.114226
# C     -3.593480
# dtype: float64
#
# 2023-02-14: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    133.377258
# GS     344.799286
# MS      91.595657
# BAC     32.924606
# C       46.733311
# Name: 2023-02-14 00:00:00, dtype: float64
# JPM   -0.119957
# GS     0.471024
# MS    -1.474519
# BAC    2.252897
# C     -3.108590
# dtype: float64
#
# 2023-02-15: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    133.936096
# GS     347.173462
# MS      91.841591
# BAC     32.869144
# C       46.923466
# Name: 2023-02-15 00:00:00, dtype: float64
# JPM   -0.192524
# GS    -0.207840
# MS     0.001094
# BAC    2.289725
# C     -0.505187
# dtype: float64
#
# 2023-02-16: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.091919
# GS     343.333923
# MS      90.693916
# BAC     32.610332
# C       46.597485
# Name: 2023-02-16 00:00:00, dtype: float64
# JPM    0.663059
# GS     0.118980
# MS     0.723658
# BAC   -0.432090
# C     -0.645481
# dtype: float64
#
# 2023-02-17: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.483109
# GS     341.757263
# MS      90.639259
# BAC     32.675041
# C       46.561264
# Name: 2023-02-17 00:00:00, dtype: float64
# JPM   -0.404272
# GS     0.221183
# MS     0.081413
# BAC   -1.127820
# C      0.222617
# dtype: float64
#
# 2023-02-20: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.483109
# GS     341.757263
# MS      90.639259
# BAC     32.675041
# C       46.561264
# Name: 2023-02-20 00:00:00, dtype: float64
# JPM   -2.745994e-14
# GS     0.000000e+00
# MS    -4.013690e-14
# BAC   -1.113382e-13
# C     -7.813316e-14
# dtype: float64
#
# Error occured here
# 2023-02-21: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.052155
# GS     334.912842
# MS      88.917740
# BAC     31.907843
# C       45.130562
# Name: 2023-02-21 00:00:00, dtype: float64
# JPM   -0.032453
# GS     0.073046
# MS     0.076330
# BAC    2.616394
# C      4.595110
# dtype: float64
#
# 2023-02-22: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    129.055542
# GS     334.699585
# MS      88.598946
# BAC     31.695244
# C       45.311665
# Name: 2023-02-22 00:00:00, dtype: float64
# JPM    0.681265
# GS    -0.089512
# MS     0.220171
# BAC    2.244490
# C     -2.382729
# dtype: float64
#
# 2023-02-23: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.089386
# GS     337.157257
# MS      89.209213
# BAC     31.667511
# C       45.619537
# Name: 2023-02-23 00:00:00, dtype: float64
# JPM   -0.426774
# GS    -0.131512
# MS    -0.411687
# BAC    2.942950
# C     -0.770783
# dtype: float64
#
# 2023-02-24: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    131.262955
# GS     337.444733
# MS      88.990608
# BAC     31.621302
# C       45.438435
# Name: 2023-02-24 00:00:00, dtype: float64
# JPM   -1.113037
# GS    -0.025924
# MS     0.525821
# BAC    0.952686
# C      1.592066
# dtype: float64
#
# 2023-02-27: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.408600
# GS     339.002777
# MS      88.079758
# BAC     31.621302
# C       45.701031
# Name: 2023-02-27 00:00:00, dtype: float64
# JPM   -0.920532
# GS    -0.155584
# MS     2.237524
# BAC    0.788040
# C     -1.581767
# dtype: float64
#
# 2023-02-28: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    133.516968
# GS     326.130096
# MS      87.897575
# BAC     31.704493
# C       45.900246
# Name: 2023-02-28 00:00:00, dtype: float64
# JPM   -1.575063
# GS     1.748873
# MS    -0.391901
# BAC   -3.583300
# C     -3.109336
# dtype: float64
#
# 2023-03-01: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.771851
# GS     323.402649
# MS      87.615227
# BAC     31.556595
# C       46.633713
# Name: 2023-03-01 00:00:00, dtype: float64
# JPM    0.582119
# GS     0.383318
# MS     0.428649
# BAC    1.962363
# C     -6.098690
# dtype: float64
#
# 2023-03-02: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    131.393372
# GS     326.083435
# MS      87.515030
# BAC     31.156559
# C       46.543152
# Name: 2023-03-02 00:00:00, dtype: float64
# JPM    0.944710
# GS    -0.578994
# MS    -0.350893
# BAC    5.218255
# C     -0.372304
# dtype: float64
#
# 2023-03-03: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    133.805725
# GS     333.546631
# MS      89.564468
# BAC     31.779877
# C       47.403381
# Name: 2023-03-03 00:00:00, dtype: float64
# JPM   -0.145798
# GS    -0.285308
# MS    -1.161534
# BAC   -1.479434
# C     -0.454770
# dtype: float64
#
# 2023-03-06: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    133.023346
# GS     333.509247
# MS      89.609993
# BAC     31.714756
# C       47.249451
# Name: 2023-03-06 00:00:00, dtype: float64
# JPM    0.518242
# GS    -0.085576
# MS    -0.436164
# BAC    0.138219
# C      0.523778
# dtype: float64
#
# 2023-03-07: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    129.111420
# GS     323.262482
# MS      87.496803
# BAC     30.700697
# C       46.253395
# Name: 2023-03-07 00:00:00, dtype: float64
# JPM    0.869010
# GS     0.416168
# MS     0.152651
# BAC    5.072997
# C     -0.628749
# dtype: float64
#
# 2023-03-08: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    128.347687
# GS     326.260895
# MS      87.351067
# BAC     30.291357
# C       45.891190
# Name: 2023-03-08 00:00:00, dtype: float64
# JPM    0.344955
# GS    -0.636257
# MS    -0.299763
# BAC    5.521780
# C      1.656840
# dtype: float64
#
# 2023-03-09: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    121.399391
# GS     319.535583
# MS      83.980911
# BAC     28.412102
# C       44.007725
# Name: 2023-03-09 00:00:00, dtype: float64
# JPM     2.459541
# GS     -0.799341
# MS      0.494501
# BAC    15.105843
# C       1.867548
# dtype: float64
#
# 2023-03-10: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    124.482353
# GS     306.066345
# MS      82.022575
# BAC     28.160913
# C       43.772301
# Name: 2023-03-10 00:00:00, dtype: float64
# JPM   -4.407219
# GS     1.723187
# MS     2.772283
# BAC   -0.115145
# C     -1.344651
# dtype: float64
#
# 2023-03-13: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    122.246964
# GS     294.708069
# MS      80.146202
# BAC     26.523540
# C       40.512466
# Name: 2023-03-13 00:00:00, dtype: float64
# JPM    -2.212772
# GS      0.108046
# MS     -2.406314
# BAC    13.718570
# C      15.344248
# dtype: float64
#
# 2023-03-14: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    125.385773
# GS     300.910278
# MS      81.949699
# BAC     26.756126
# C       42.921120
# Name: 2023-03-14 00:00:00, dtype: float64
# JPM    -0.336263
# GS      0.094286
# MS      0.075336
# BAC     8.049054
# C     -12.969713
# dtype: float64
#
# 2023-03-15: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    119.462051
# GS     291.606964
# MS      77.777977
# BAC     26.504938
# C       40.584908
# Name: 2023-03-15 00:00:00, dtype: float64
# JPM     1.968940
# GS     -0.065739
# MS      3.757739
# BAC   -13.379074
# C       8.554497
# dtype: float64
#
# 2023-03-16: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    121.781273
# GS     294.315674
# MS      79.253555
# BAC     26.951488
# C       41.309319
# Name: 2023-03-16 00:00:00, dtype: float64
# JPM   -0.703997
# GS     0.227477
# MS    -0.997624
# BAC   -1.745272
# C     -1.504249
# dtype: float64
#
# 2023-03-17: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    117.180115
# GS     283.527252
# MS      76.675835
# BAC     25.881620
# C       40.068771
# Name: 2023-03-17 00:00:00, dtype: float64
# JPM    1.087206
# GS     0.388615
# MS     0.613400
# BAC    6.052824
# C      0.222188
# dtype: float64
#
# 2023-03-20: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    118.418884
# GS     289.122314
# MS      78.005692
# BAC     25.816498
# C       39.923889
# Name: 2023-03-20 00:00:00, dtype: float64
# JPM   -0.457558
# GS    -0.657583
# MS    -1.982724
# BAC    5.422704
# C      3.915217
# dtype: float64
#
# 2023-03-21: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    121.594978
# GS     296.361359
# MS      80.847565
# BAC     26.597967
# C       40.811283
# Name: 2023-03-21 00:00:00, dtype: float64
# JPM   -0.412352
# GS    -0.079313
# MS    -2.396107
# BAC   -3.822499
# C      0.452994
# dtype: float64
#
# 2023-03-22: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    118.456139
# GS     292.989410
# MS      79.745422
# BAC     25.714163
# C       39.579792
# Name: 2023-03-22 00:00:00, dtype: float64
# JPM    0.874621
# GS    -0.399751
# MS    -1.036439
# BAC    8.437757
# C      4.302435
# dtype: float64
#
# 2023-03-23: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    118.139465
# GS     294.091553
# MS      78.187851
# BAC     25.090841
# C       39.344364
# Name: 2023-03-23 00:00:00, dtype: float64
# JPM   -0.689642
# GS    -0.605228
# MS     2.191955
# BAC    9.645273
# C     -0.822350
# dtype: float64
#
# 2023-03-24: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    116.341858
# GS     291.961914
# MS      76.466339
# BAC     25.248997
# C       39.036491
# Name: 2023-03-24 00:00:00, dtype: float64
# JPM    0.965443
# GS    -0.021642
# MS     2.792234
# BAC   -8.231134
# C      0.060577
# dtype: float64
#
# 2023-03-27: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    119.676285
# GS     297.528961
# MS      77.094833
# BAC     26.504938
# C       40.548687
# Name: 2023-03-27 00:00:00, dtype: float64
# JPM    -0.566136
# GS      0.248275
# MS      3.035589
# BAC   -14.298725
# C      -5.339962
# dtype: float64
#
# 2023-03-28: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    120.039536
# GS     297.444916
# MS      77.313431
# BAC     26.160717
# C       40.947117
# Name: 2023-03-28 00:00:00, dtype: float64
# JPM   -0.331336
# GS     0.034919
# MS    -0.475365
# BAC    7.739177
# C     -3.478616
# dtype: float64
#
# 2023-03-29: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    120.281700
# GS     299.574554
# MS      78.552208
# BAC     26.672394
# C       41.608124
# Name: 2023-03-29 00:00:00, dtype: float64
# JPM    1.022671
# GS     0.150984
# MS    -1.130711
# BAC   -5.335243
# C     -2.178350
# dtype: float64
#
# 2023-03-30: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    119.918457
# GS     299.966888
# MS      78.433792
# BAC     26.328175
# C       41.716793
# Name: 2023-03-30 00:00:00, dtype: float64
# JPM    0.097850
# GS    -0.181401
# MS    -0.145010
# BAC    6.182258
# C     -1.781252
# dtype: float64
#
# 2023-03-31: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    121.371437
# GS     305.543274
# MS      79.973137
# BAC     26.607271
# C       42.459316
# Name: 2023-03-31 00:00:00, dtype: float64
# JPM    0.126306
# GS    -0.272802
# MS    -1.239742
# BAC    1.444542
# C     -1.679186
# dtype: float64
#
# 2023-04-03: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    121.231728
# GS     304.992157
# MS      79.390198
# BAC     26.597967
# C       42.296314
# Name: 2023-04-03 00:00:00, dtype: float64
# JPM   -0.159795
# GS    -0.030469
# MS     0.950041
# BAC   -1.193666
# C      0.523446
# dtype: float64
#
# 2023-04-04: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    119.611092
# GS     301.377289
# MS      77.258774
# BAC     26.030472
# C       41.734901
# Name: 2023-04-04 00:00:00, dtype: float64
# JPM   -0.138869
# GS    -0.132602
# MS     2.473024
# BAC    4.077912
# C     -0.432977
# dtype: float64
#
# 2023-04-05: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    119.789436
# GS     300.331146
# MS      76.347923
# BAC     25.714163
# C       41.445133
# Name: 2023-04-05 00:00:00, dtype: float64
# JPM   -0.883299
# GS    -0.101429
# MS     1.255383
# BAC    3.941047
# C      0.536978
# dtype: float64
#
# 2023-04-06: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    119.658020
# GS     301.143799
# MS      76.684944
# BAC     25.900227
# C       41.526634
# Name: 2023-04-06 00:00:00, dtype: float64
# JPM    0.458695
# GS    -0.008439
# MS    -0.369567
# BAC   -2.739312
# C      0.207674
# dtype: float64
#
# 2023-04-10: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    120.052284
# GS     303.535034
# MS      76.511887
# BAC     25.993259
# C       42.124271
# Name: 2023-04-10 00:00:00, dtype: float64
# JPM    0.151176
# GS    -0.171914
# MS     1.335706
# BAC    0.525210
# C     -3.557287
# dtype: float64
#
# 2023-04-11: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    120.643677
# GS     305.786102
# MS      77.504707
# BAC     26.709610
# C       42.740021
# Name: 2023-04-11 00:00:00, dtype: float64
# JPM    0.797028
# GS     0.190621
# MS    -0.338836
# BAC   -9.286217
# C     -1.198479
# dtype: float64
#
# 2023-04-12: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    120.624901
# GS     308.466888
# MS      77.850838
# BAC     26.495632
# C       42.486477
# Name: 2023-04-12 00:00:00, dtype: float64
# JPM    0.001433
# GS    -0.444265
# MS    -0.910709
# BAC    4.566044
# C      2.094972
# dtype: float64
#
# 2023-04-13: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    121.084869
# GS     310.232300
# MS      78.051231
# BAC     26.570061
# C       42.830570
# Name: 2023-04-13 00:00:00, dtype: float64
# JPM    0.002945
# GS    -0.093515
# MS     0.248682
# BAC    0.594514
# C     -1.530235
# dtype: float64
#
# 2023-04-14: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.227966
# GS     314.706482
# MS      78.980309
# BAC     27.463173
# C       44.877022
# Name: 2023-04-14 00:00:00, dtype: float64
# JPM   -5.330243
# GS     0.790436
# MS     3.641803
# BAC   -1.728433
# C     -5.930292
# dtype: float64
#
# 2023-04-17: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    131.260544
# GS     317.284485
# MS      81.330315
# BAC     28.253946
# C       44.994740
# Name: 2023-04-17 00:00:00, dtype: float64
# JPM    0.600224
# GS     0.235139
# MS    -3.299880
# BAC   -8.958185
# C      3.626735
# dtype: float64
#
# 2023-04-18: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.734314
# GS     311.894897
# MS      81.840385
# BAC     28.430710
# C       45.347889
# Name: 2023-04-18 00:00:00, dtype: float64
# JPM   -1.067128
# GS     1.003323
# MS    -0.755036
# BAC   -2.164739
# C     -1.922948
# dtype: float64
#
# 2023-04-19: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.565369
# GS     314.678467
# MS      82.386917
# BAC     27.965546
# C       45.637646
# Name: 2023-04-19 00:00:00, dtype: float64
# JPM    0.243564
# GS    -0.420776
# MS    -1.166732
# BAC    9.868526
# C     -2.004177
# dtype: float64
#
# 2023-04-20: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.180481
# GS     316.378479
# MS      82.368690
# BAC     27.816692
# C       44.732140
# Name: 2023-04-20 00:00:00, dtype: float64
# JPM   -0.111391
# GS    -0.470845
# MS    -0.705047
# BAC    0.876418
# C      5.790762
# dtype: float64
#
# 2023-04-21: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    131.927032
# GS     319.133972
# MS      82.997177
# BAC     27.788784
# C       44.397099
# Name: 2023-04-21 00:00:00, dtype: float64
# JPM    0.354609
# GS    -0.389553
# MS    -1.288497
# BAC    1.153848
# C      3.074621
# dtype: float64
#
# 2023-04-24: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.105377
# GS     321.282288
# MS      82.159187
# BAC     27.686445
# C       44.397099
# Name: 2023-04-24 00:00:00, dtype: float64
# JPM   -0.280737
# GS    -0.385308
# MS     1.794377
# BAC    1.591177
# C     -0.344608
# dtype: float64
#
# 2023-04-25: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    129.232925
# GS     317.097656
# MS      80.209953
# BAC     26.830549
# C       43.373878
# Name: 2023-04-25 00:00:00, dtype: float64
# JPM    0.373931
# GS    -0.290326
# MS     1.000229
# BAC    7.304299
# C      1.597970
# dtype: float64
#
# 2023-04-26: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    126.942444
# GS     314.370239
# MS      80.556091
# BAC     26.458422
# C       42.432140
# Name: 2023-04-26 00:00:00, dtype: float64
# JPM    1.011281
# GS    -0.050124
# MS    -2.728966
# BAC    2.550443
# C      4.510502
# dtype: float64
#
# 2023-04-27: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    128.650925
# GS     319.077972
# MS      82.213844
# BAC     26.877066
# C       42.586082
# Name: 2023-04-27 00:00:00, dtype: float64
# JPM   -0.249118
# GS    -0.174811
# MS    -1.745028
# BAC   -2.568779
# C      2.859667
# dtype: float64
#
# 2023-04-28: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    129.767975
# GS     320.796600
# MS      82.659439
# BAC     27.239895
# C       43.089573
# Name: 2023-04-28 00:00:00, dtype: float64
# JPM   -0.148087
# GS     0.102733
# MS     0.392244
# BAC   -3.504051
# C     -1.599312
# dtype: float64
#
# 2023-05-01: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.546570
# GS     318.115814
# MS      80.785194
# BAC     27.016613
# C       43.254349
# Name: 2023-05-01 00:00:00, dtype: float64
# JPM   -2.856291
# GS     0.301972
# MS     4.015008
# BAC    3.461368
# C     -2.269267
# dtype: float64
#
# 2023-05-02: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.406281
# GS     311.390472
# MS      79.278442
# BAC     26.197931
# C       42.110050
# Name: 2023-05-02 00:00:00, dtype: float64
# JPM   -0.321496
# GS     0.120469
# MS    -0.026418
# BAC    6.994961
# C      2.898229
# dtype: float64
#
# 2023-05-03: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    127.646492
# GS     306.981689
# MS      77.863586
# BAC     25.918833
# C       41.807961
# Name: 2023-05-03 00:00:00, dtype: float64
# JPM    1.140939
# GS     0.118259
# MS     1.205607
# BAC   -0.710072
# C     -1.739313
# dtype: float64
#
# 2023-05-04: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    125.900490
# GS     300.078949
# MS      75.897476
# BAC     25.109449
# C       41.103077
# Name: 2023-05-04 00:00:00, dtype: float64
# JPM   -0.560118
# GS     0.217700
# MS     1.422612
# BAC    7.971541
# C     -0.521753
# dtype: float64
#
# 2023-05-05: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    128.359894
# GS     305.459137
# MS      77.983017
# BAC     25.779282
# C       42.402992
# Name: 2023-05-05 00:00:00, dtype: float64
# JPM    0.118704
# GS     0.129460
# MS    -1.347141
# BAC   -3.604110
# C     -3.958580
# dtype: float64
#
# 2023-05-08: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    128.669678
# GS     304.982788
# MS      77.569588
# BAC     25.760675
# C       42.439613
# Name: 2023-05-08 00:00:00, dtype: float64
# JPM   -0.376044
# GS     0.042656
# MS     0.913220
# BAC    0.002481
# C     -0.575787
# dtype: float64
#
# 2023-05-09: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    128.050156
# GS     303.357513
# MS      77.514458
# BAC     25.732769
# C       42.586086
# Name: 2023-05-09 00:00:00, dtype: float64
# JPM    0.410079
# GS     0.199276
# MS    -0.140195
# BAC   -0.198718
# C     -1.764416
# dtype: float64
#
# 2023-05-10: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    128.115845
# GS     301.283875
# MS      76.917290
# BAC     25.416456
# C       42.448769
# Name: 2023-05-10 00:00:00, dtype: float64
# JPM   -0.654410
# GS     0.097849
# MS     0.557361
# BAC    4.470521
# C     -0.617356
# dtype: float64
#
# 2023-05-11: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    127.712196
# GS     299.574554
# MS      75.915855
# BAC     25.481579
# C       42.137520
# Name: 2023-05-11 00:00:00, dtype: float64
# JPM   -0.154393
# GS     0.063403
# MS     1.735067
# BAC   -4.214044
# C      1.054858
# dtype: float64
#
# 2023-05-12: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    125.881699
# GS     298.434998
# MS      75.695351
# BAC     25.202484
# C       41.606564
# Name: 2023-05-12 00:00:00, dtype: float64
# JPM    0.837429
# GS    -0.185744
# MS    -0.913809
# BAC    2.133874
# C      1.897565
# dtype: float64
#
# 2023-05-15: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    126.942444
# GS     300.835510
# MS      76.209846
# BAC     25.723463
# C       42.155827
# Name: 2023-05-15 00:00:00, dtype: float64
# JPM    0.131017
# GS     0.074582
# MS     0.542468
# BAC   -6.571597
# C     -1.322945
# dtype: float64
#
# 2023-05-16: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    126.088219
# GS     299.658600
# MS      75.208405
# BAC     25.453671
# C       41.450947
# Name: 2023-05-16 00:00:00, dtype: float64
# JPM   -0.214795
# GS    -0.234286
# MS     0.944829
# BAC    1.196581
# C      3.036447
# dtype: float64
#
# 2023-05-17: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    129.965134
# GS     308.410858
# MS      77.091850
# BAC     26.579361
# C       43.098728
# Name: 2023-05-17 00:00:00, dtype: float64
# JPM   -0.301881
# GS    -0.051417
# MS     0.614171
# BAC   -9.172050
# C     -4.081463
# dtype: float64
#
# 2023-05-18: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.950760
# GS     307.850372
# MS      77.624725
# BAC     26.486330
# C       42.467075
# Name: 2023-05-18 00:00:00, dtype: float64
# JPM   -1.012516
# GS     0.045846
# MS    -1.573082
# BAC    1.524305
# C      5.050002
# dtype: float64
#
# 2023-05-19: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.650360
# GS     304.646515
# MS      75.557549
# BAC     26.151411
# C       41.844582
# Name: 2023-05-19 00:00:00, dtype: float64
# JPM   -1.051523
# GS    -0.035752
# MS     3.203366
# BAC    0.917606
# C      1.323594
# dtype: float64
#
# 2023-05-22: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    129.570847
# GS     303.497711
# MS      75.585091
# BAC     26.365389
# C       41.917816
# Name: 2023-05-22 00:00:00, dtype: float64
# JPM    0.948721
# GS     0.176858
# MS    -0.133391
# BAC   -4.953938
# C     -0.750168
# dtype: float64
#
# 2023-05-23: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    128.219086
# GS     302.236633
# MS      75.925041
# BAC     26.588665
# C       42.027664
# Name: 2023-05-23 00:00:00, dtype: float64
# JPM    1.274102
# GS     0.220389
# MS    -0.879228
# BAC   -4.812568
# C     -0.899995
# dtype: float64
#
# 2023-05-24: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    127.045715
# GS     298.724518
# MS      74.620422
# BAC     26.142111
# C       40.727753
# Name: 2023-05-24 00:00:00, dtype: float64
# JPM   -0.622303
# GS    -0.137243
# MS     0.599736
# BAC    1.483052
# C      6.302082
# dtype: float64
#
# 2023-05-25: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    127.355453
# GS     302.526215
# MS      76.255791
# BAC     26.207232
# C       40.489727
# Name: 2023-05-25 00:00:00, dtype: float64
# JPM    0.379800
# GS    -0.356888
# MS    -3.247034
# BAC    1.814915
# C      4.302902
# dtype: float64
#
# 2023-05-26: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    128.547653
# GS     310.120178
# MS      77.082649
# BAC     26.337479
# C       40.828442
# Name: 2023-05-26 00:00:00, dtype: float64
# JPM    0.049023
# GS    -0.755285
# MS    -0.212043
# BAC    2.787090
# C      0.527031
# dtype: float64
#
# 2023-05-29: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    128.547653
# GS     310.120178
# MS      77.082649
# BAC     26.337479
# C       40.828442
# Name: 2023-05-29 00:00:00, dtype: float64
# JPM   -2.830062e-14
# GS     5.865434e-15
# MS     0.000000e+00
# BAC    0.000000e+00
# C      0.000000e+00
# dtype: float64
#
# Error occured here
# 2023-05-30: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    129.035782
# GS     309.017975
# MS      76.641647
# BAC     26.290958
# C       40.919987
# Name: 2023-05-30 00:00:00, dtype: float64
# JPM   -0.553774
# GS     0.135839
# MS     0.983992
# BAC    0.547359
# C     -1.159862
# dtype: float64
#
# 2023-05-31: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    127.393044
# GS     304.848541
# MS      75.116554
# BAC     25.853712
# C       40.572124
# Name: 2023-05-31 00:00:00, dtype: float64
# JPM    0.103489
# GS     0.081767
# MS     1.646743
# BAC    2.835735
# C     -1.282389
# dtype: float64
#
# 2023-06-01: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    129.148438
# GS     297.789673
# MS      75.401352
# BAC     26.050634
# C       41.048149
# Name: 2023-06-01 00:00:00, dtype: float64
# JPM   -1.354786
# GS     1.301942
# MS    -0.302506
# BAC   -3.112642
# C     -3.502978
# dtype: float64
#
# 2023-06-02: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    131.861313
# GS     304.613220
# MS      77.496094
# BAC     26.922739
# C       42.402992
# Name: 2023-06-02 00:00:00, dtype: float64
# JPM    0.234477
# GS     0.005854
# MS    -0.935995
# BAC   -5.924750
# C     -3.592134
# dtype: float64
#
# 2023-06-05: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.565887
# GS     302.881500
# MS      76.935661
# BAC     26.763327
# C       42.329762
# Name: 2023-06-05 00:00:00, dtype: float64
# JPM    0.569404
# GS     0.031984
# MS     0.439967
# BAC    0.499778
# C     -1.231750
# dtype: float64
#
# 2023-06-06: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.800583
# GS     307.577972
# MS      78.883392
# BAC     27.410368
# C       43.226883
# Name: 2023-06-06 00:00:00, dtype: float64
# JPM    1.528917
# GS    -0.042495
# MS    -2.098557
# BAC   -5.393016
# C     -2.347308
# dtype: float64
#
# 2023-06-07: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.067825
# GS     316.001526
# MS      79.471390
# BAC     27.644808
# C       43.950085
# Name: 2023-06-07 00:00:00, dtype: float64
# JPM    0.232489
# GS    -0.786052
# MS     0.829724
# BAC    1.758347
# C     -1.828121
# dtype: float64
#
# 2023-06-08: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.105377
# GS     315.737976
# MS      79.296822
# BAC     27.410368
# C       44.032475
# Name: 2023-06-08 00:00:00, dtype: float64
# JPM   -0.222565
# GS    -0.036615
# MS     0.128341
# BAC    4.028545
# C     -1.243904
# dtype: float64
#
# 2023-06-09: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.368210
# GS     316.255615
# MS      79.204956
# BAC     27.447880
# C       44.215557
# Name: 2023-06-09 00:00:00, dtype: float64
# JPM   -0.079028
# GS    -0.015444
# MS     0.501012
# BAC   -0.020718
# C     -1.017711
# dtype: float64
#
# 2023-06-12: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.358841
# GS     319.521545
# MS      80.335007
# BAC     27.316595
# C       44.352879
# Name: 2023-06-12 00:00:00, dtype: float64
# JPM    0.467365
# GS    -0.325417
# MS    -2.076653
# BAC    5.015948
# C      0.252432
# dtype: float64
#
# 2023-06-13: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    133.316315
# GS     322.354553
# MS      81.106758
# BAC     27.569788
# C       44.572578
# Name: 2023-06-13 00:00:00, dtype: float64
# JPM   -0.069539
# GS    -0.109839
# MS    -0.582675
# BAC   -1.517969
# C      0.611145
# dtype: float64
#
# 2023-06-14: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    132.818817
# GS     318.514496
# MS      80.831131
# BAC     27.307217
# C       44.160637
# Name: 2023-06-14 00:00:00, dtype: float64
# JPM   -0.311819
# GS     0.283922
# MS    -0.578843
# BAC    1.901912
# C      1.073208
# dtype: float64
#
# 2023-06-15: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    134.320755
# GS     319.756805
# MS      81.814194
# BAC     27.541655
# C       44.453575
# Name: 2023-06-15 00:00:00, dtype: float64
# JPM   -0.501963
# GS     0.160167
# MS    -0.991238
# BAC   -0.864690
# C      0.167422
# dtype: float64
#
# 2023-06-16: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    134.480331
# GS     318.410950
# MS      80.932175
# BAC     27.372862
# C       44.114861
# Name: 2023-06-16 00:00:00, dtype: float64
# JPM   -0.693187
# GS    -0.019383
# MS     1.233426
# BAC    0.905641
# C      1.107026
# dtype: float64
#
# 2023-06-19: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    134.480331
# GS     318.410950
# MS      80.932175
# BAC     27.372862
# C       44.114861
# Name: 2023-06-19 00:00:00, dtype: float64
# JPM   -1.352606e-14
# GS    -5.712710e-15
# MS     0.000000e+00
# BAC    0.000000e+00
# C      0.000000e+00
# dtype: float64
#
# Error occured here
# 2023-06-20: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    133.795059
# GS     311.267395
# MS      79.682716
# BAC     27.072783
# C       43.583904
# Name: 2023-06-20 00:00:00, dtype: float64
# JPM   -0.707842
# GS     0.590087
# MS     0.895351
# BAC   -0.018931
# C      0.383540
# dtype: float64
#
# 2023-06-21: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    133.597931
# GS     305.949707
# MS      79.324394
# BAC     26.791456
# C       43.400818
# Name: 2023-06-21 00:00:00, dtype: float64
# JPM   -0.570614
# GS     0.561002
# MS    -0.355812
# BAC    2.440045
# C     -0.758647
# dtype: float64
#
# 2023-06-22: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    131.025848
# GS     300.782623
# MS      77.633904
# BAC     26.219431
# C       42.686787
# Name: 2023-06-22 00:00:00, dtype: float64
# JPM    0.406618
# GS     0.053130
# MS     1.104687
# BAC    3.294928
# C      0.212967
# dtype: float64
#
# 2023-06-23: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.340607
# GS     296.199127
# MS      76.788658
# BAC     26.022505
# C       42.128365
# Name: 2023-06-23 00:00:00, dtype: float64
# JPM   -0.408429
# GS     0.344982
# MS     0.450850
# BAC   -0.684675
# C      1.630571
# dtype: float64
#
# 2023-06-26: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.659744
# GS     293.987366
# MS      76.797836
# BAC     26.341337
# C       42.329762
# Name: 2023-06-26 00:00:00, dtype: float64
# JPM   -0.050216
# GS     0.496886
# MS     0.381397
# BAC   -5.978330
# C     -1.003089
# dtype: float64
#
# 2023-06-27: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.669113
# GS     295.013153
# MS      77.569588
# BAC     26.481998
# C       42.476227
# Name: 2023-06-27 00:00:00, dtype: float64
# JPM    0.432438
# GS     0.012851
# MS    -1.255579
# BAC   -0.934819
# C      0.099833
# dtype: float64
#
# 2023-06-28: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    130.096542
# GS     295.210785
# MS      77.165344
# BAC     26.322586
# C       42.320606
# Name: 2023-06-28 00:00:00, dtype: float64
# JPM    0.152417
# GS    -0.197774
# MS     0.423404
# BAC    1.716641
# C      0.205821
# dtype: float64
#
# 2023-06-29: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    134.639908
# GS     304.086212
# MS      78.313782
# BAC     26.875854
# C       42.375534
# Name: 2023-06-29 00:00:00, dtype: float64
# JPM   -2.051040
# GS    -0.661543
# MS     0.423417
# BAC   -2.290019
# C      5.730574
# dtype: float64
#
# 2023-06-30: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    136.526733
# GS     303.568512
# MS      78.460762
# BAC     26.903988
# C       42.146675
# Name: 2023-06-30 00:00:00, dtype: float64
# JPM   -1.422817
# GS     0.172789
# MS    -0.047570
# BAC    0.345555
# C      2.621942
# dtype: float64
#
# 2023-07-03: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    137.625015
# GS     307.399139
# MS      79.388718
# BAC     27.382236
# C       42.787483
# Name: 2023-07-03 00:00:00, dtype: float64
# JPM    0.327578
# GS    -0.087307
# MS    -0.181269
# BAC   -3.941587
# C     -1.577364
# dtype: float64
#
# 2023-07-04: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    137.625015
# GS     307.399139
# MS      79.388718
# BAC     27.382236
# C       42.787483
# Name: 2023-07-04 00:00:00, dtype: float64
# JPM   -2.643399e-14
# GS     0.000000e+00
# MS     0.000000e+00
# BAC    0.000000e+00
# C      0.000000e+00
# dtype: float64
#
# Error occured here
# 2023-07-05: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    136.708221
# GS     301.225006
# MS      78.938499
# BAC     27.269707
# C       42.842403
# Name: 2023-07-05 00:00:00, dtype: float64
# JPM    0.091570
# GS     0.749876
# MS    -0.040853
# BAC   -1.028392
# C     -2.655462
# dtype: float64
#
# 2023-07-06: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    135.356628
# GS     294.589691
# MS      76.558975
# BAC     26.519516
# C       41.542488
# Name: 2023-07-06 00:00:00, dtype: float64
# JPM   -1.178867
# GS     0.109568
# MS     2.096753
# BAC    4.483670
# C      3.939345
# dtype: float64
#
# 2023-07-07: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    136.424652
# GS     296.632050
# MS      76.586525
# BAC     26.753946
# C       41.872047
# Name: 2023-07-07 00:00:00, dtype: float64
# JPM   -0.291086
# GS    -0.083886
# MS     1.004144
# BAC   -2.033885
# C     -0.964161
# dtype: float64
#
# 2023-07-10: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    137.190216
# GS     297.855591
# MS      76.623283
# BAC     26.875854
# C       41.807961
# Name: 2023-07-10 00:00:00, dtype: float64
# JPM   -0.386340
# GS    -0.100232
# MS     0.350909
# BAC   -1.361001
# C      1.391776
# dtype: float64
#
# 2023-07-11: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    139.335770
# GS     302.006134
# MS      78.056519
# BAC     27.213444
# C       42.595242
# Name: 2023-07-11 00:00:00, dtype: float64
# JPM   -0.264352
# GS    -0.033904
# MS    -1.084673
# BAC    0.411323
# C     -2.033810
# dtype: float64
#
# 2023-07-12: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    140.025726
# GS     307.201508
# MS      78.800705
# BAC     27.532276
# C       43.373360
# ...
# JPM    296.681732
# GS     770.211670
# MS     158.169998
# BAC     51.293442
# C       98.699997
# Name: 2025-11-21 00:00:00, dtype: float64
# JPM    0.432609
# GS     0.101483
# MS     1.225870
# BAC   -4.798969
# C     -2.487542
# dtype: float64
#
# 2025-11-24: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    296.661835
# GS     786.809387
# MS     162.830002
# BAC     51.661530
# C       99.690002
# Name: 2025-11-24 00:00:00, dtype: float64
# JPM    1.187035
# GS    -0.399205
# MS    -3.426691
# BAC    2.495195
# C      0.410594
# dtype: float64
#
# 2025-11-25: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    301.639374
# GS     798.362122
# MS     165.429993
# BAC     52.208683
# C      101.169998
# Name: 2025-11-25 00:00:00, dtype: float64
# JPM   -0.478887
# GS    -0.099119
# MS    -0.720379
# BAC    0.927356
# C     -0.832388
# dtype: float64
#
# 2025-11-26: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    306.258545
# GS     811.984558
# MS     167.940002
# BAC     52.716049
# C      102.500000
# Name: 2025-11-26 00:00:00, dtype: float64
# JPM   -0.368591
# GS    -0.206996
# MS    -0.645697
# BAC    1.207457
# C     -0.434196
# dtype: float64
#
# 2025-11-27: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    306.258545
# GS     811.984558
# MS     167.940002
# BAC     52.716049
# C      102.500000
# Name: 2025-11-27 00:00:00, dtype: float64
# JPM    1.187878e-14
# GS     4.480355e-15
# MS     2.166237e-14
# BAC    0.000000e+00
# C      3.549248e-14
# dtype: float64
#
# Error occured here
# 2025-11-28: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    311.674103
# GS     821.965088
# MS     169.660004
# BAC     53.372639
# C      103.599998
# Name: 2025-11-28 00:00:00, dtype: float64
# JPM   -0.728757
# GS    -0.066962
# MS     0.061227
# BAC   -1.129144
# C     -0.050684
# dtype: float64
#
# 2025-12-01: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    307.532806
# GS     806.859985
# MS     168.470001
# BAC     52.964756
# C      102.680000
# Name: 2025-12-01 00:00:00, dtype: float64
# JPM    0.428704
# GS     0.366873
# MS    -0.418567
# BAC   -0.948828
# C     -0.100468
# dtype: float64
#
# 2025-12-02: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    306.497467
# GS     815.210022
# MS     169.089996
# BAC     52.915012
# C      103.190002
# Name: 2025-12-02 00:00:00, dtype: float64
# JPM    0.606362
# GS    -0.309739
# MS    -0.232829
# BAC    2.046055
# C     -0.780060
# dtype: float64
#
# 2025-12-03: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    310.728394
# GS     836.570007
# MS     173.720001
# BAC     53.810364
# C      106.720001
# Name: 2025-12-03 00:00:00, dtype: float64
# JPM    0.613365
# GS    -0.246981
# MS    -1.407004
# BAC    1.686350
# C     -4.339838
# dtype: float64
#
# 2025-12-04: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    314.680573
# GS     837.830017
# MS     174.889999
# BAC     53.880001
# C      107.790001
# Name: 2025-12-04 00:00:00, dtype: float64
# JPM   -0.761967
# GS     0.151066
# MS    -0.253106
# BAC    2.477635
# C     -1.408263
# dtype: float64
#
# 2025-12-05: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    313.625336
# GS     854.559998
# MS     176.509995
# BAC     53.950001
# C      108.879997
# Name: 2025-12-05 00:00:00, dtype: float64
# JPM    1.002122
# GS    -0.528648
# MS    -0.567225
# BAC    2.992906
# C     -1.175769
# dtype: float64
#
# 2025-12-08: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    313.794556
# GS     866.690002
# MS     176.830002
# BAC     53.900002
# C      108.919998
# Name: 2025-12-08 00:00:00, dtype: float64
# JPM    0.223827
# GS    -0.439694
# MS     0.159179
# BAC    2.202227
# C      0.697083
# dtype: float64
#
# 2025-12-09: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    299.160583
# GS     876.580017
# MS     178.830002
# BAC     53.540001
# C      109.430000
# Name: 2025-12-09 00:00:00, dtype: float64
# JPM    4.687678
# GS    -0.594669
# MS    -2.896211
# BAC    1.461137
# C     -2.725783
# dtype: float64
#
# 2025-12-10: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    308.717438
# GS     889.239990
# MS     179.710007
# BAC     54.080002
# C      111.089996
# Name: 2025-12-10 00:00:00, dtype: float64
# JPM   -2.050520
# GS    -0.062403
# MS     1.439464
# BAC    1.631999
# C     -0.715459
# dtype: float64
#
# 2025-12-11: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    315.954803
# GS     911.030029
# MS     180.289993
# BAC     54.560001
# C      111.739998
# Name: 2025-12-11 00:00:00, dtype: float64
# JPM   -1.317824
# GS    -0.495946
# MS     1.437655
# BAC    1.291055
# C      1.534945
# dtype: float64
#
# 2025-12-12: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    317.089691
# GS     887.960022
# MS     178.410004
# BAC     55.139999
# C      111.800003
# Name: 2025-12-12 00:00:00, dtype: float64
# JPM   -0.755458
# GS     0.830363
# MS     1.312118
# BAC   -8.656899
# C     -1.219488
# dtype: float64
#
# 2025-12-15: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    318.582947
# GS     889.590027
# MS     177.789993
# BAC     55.330002
# C      112.800003
# Name: 2025-12-15 00:00:00, dtype: float64
# JPM   -0.225360
# GS     0.028043
# MS     1.145985
# BAC   -0.528839
# C     -1.900555
# dtype: float64
#
# 2025-12-16: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    314.133026
# GS     879.150024
# MS     176.509995
# BAC     54.810001
# C      111.279999
# Name: 2025-12-16 00:00:00, dtype: float64
# JPM    0.501975
# GS     0.093666
# MS    -0.400918
# BAC    0.062866
# C      1.267602
# dtype: float64
#
# 2025-12-17: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    313.565582
# GS     872.330017
# MS     174.800003
# BAC     54.549999
# C      111.459999
# Name: 2025-12-17 00:00:00, dtype: float64
# JPM   -0.205100
# GS     0.154401
# MS     1.139797
# BAC    0.621623
# C     -1.604218
# dtype: float64
#
# 2025-12-18: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    311.594482
# GS     876.299988
# MS     172.960007
# BAC     54.259998
# C      112.830002
# Name: 2025-12-18 00:00:00, dtype: float64
# JPM    0.577889
# GS    -0.206511
# MS     1.857817
# BAC    2.723133
# C     -3.889349
# dtype: float64
#
# 2025-12-19: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    315.785553
# GS     893.479980
# MS     176.979996
# BAC     55.270000
# C      114.860001
# Name: 2025-12-19 00:00:00, dtype: float64
# JPM    0.214344
# GS    -0.153530
# MS    -1.459143
# BAC   -1.885089
# C     -0.726711
# dtype: float64
#
# 2025-12-22: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    321.639160
# GS     899.000000
# MS     179.759995
# BAC     55.880001
# C      118.089996
# Name: 2025-12-22 00:00:00, dtype: float64
# JPM   -0.554155
# GS     0.266394
# MS    -0.459652
# BAC    1.346884
# C     -4.252690
# dtype: float64
#
# 2025-12-23: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    324.466400
# GS     901.710022
# MS     179.500000
# BAC     55.970001
# C      119.400002
# Name: 2025-12-23 00:00:00, dtype: float64
# JPM   -0.522117
# GS     0.031495
# MS     1.009348
# BAC    1.366463
# C     -2.079488
# dtype: float64
#
# 2025-12-24: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    327.691864
# GS     910.780029
# MS     181.649994
# BAC     56.250000
# C      121.559998
# Name: 2025-12-24 00:00:00, dtype: float64
# JPM   -0.079994
# GS    -0.033230
# MS    -0.529820
# BAC    2.552243
# C     -2.520576
# dtype: float64
#
# 2025-12-26: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    326.437531
# GS     907.039978
# MS     181.869995
# BAC     56.169998
# C      120.419998
# Name: 2025-12-26 00:00:00, dtype: float64
# JPM    0.096425
# GS     0.045361
# MS    -0.788222
# BAC   -0.925507
# C      1.860577
# dtype: float64
#
# 2025-12-29: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    322.296204
# GS     892.179993
# MS     179.940002
# BAC     55.349998
# C      118.129997
# Name: 2025-12-29 00:00:00, dtype: float64
# JPM    0.050484
# GS     0.161572
# MS    -0.308414
# BAC    1.489065
# C      1.991604
# dtype: float64
#
# 2025-12-30: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    321.967712
# GS     884.419983
# MS     179.080002
# BAC     55.279999
# C      117.209999
# Name: 2025-12-30 00:00:00, dtype: float64
# JPM   -0.308390
# GS     0.184417
# MS     0.163061
# BAC   -1.644429
# C      1.126294
# dtype: float64
#
# 2025-12-31: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    320.773071
# GS     879.000000
# MS     177.529999
# BAC     55.000000
# C      116.690002
# Name: 2025-12-31 00:00:00, dtype: float64
# JPM   -0.101391
# GS     0.056627
# MS     0.764898
# BAC    0.247030
# C     -0.066941
# dtype: float64
#
# 2026-01-02: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    324.018433
# GS     914.340027
# MS     181.899994
# BAC     55.950001
# C      118.699997
# Name: 2026-01-02 00:00:00, dtype: float64
# JPM    0.849227
# GS    -0.813895
# MS    -1.187597
# BAC    0.585245
# C      0.289463
# dtype: float64
#
# 2026-01-05: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    332.540009
# GS     948.440002
# MS     186.539993
# BAC     56.889999
# C      123.300003
# Name: 2026-01-05 00:00:00, dtype: float64
# JPM   -0.227209
# GS    -0.479579
# MS    -0.258732
# BAC    4.431918
# C     -4.097068
# dtype: float64
#
# 2026-01-06: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    334.609985
# GS     955.469971
# MS     187.750000
# BAC     57.250000
# C      122.500000
# Name: 2026-01-06 00:00:00, dtype: float64
# JPM   -0.305929
# GS    -0.151042
# MS    -0.594500
# BAC   -1.851796
# C      2.830773
# dtype: float64
#
# 2026-01-07: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    326.989990
# GS     941.020020
# MS     184.789993
# BAC     55.639999
# C      121.370003
# Name: 2026-01-07 00:00:00, dtype: float64
# JPM    0.824363
# GS    -0.001684
# MS     0.114628
# BAC    8.252691
# C     -1.735854
# dtype: float64
#
# 2026-01-08: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    329.790009
# GS     934.830017
# MS     184.679993
# BAC     56.180000
# C      120.599998
# Name: 2026-01-08 00:00:00, dtype: float64
# JPM   -0.822595
# GS     0.275205
# MS     0.262188
# BAC   -5.538600
# C      2.065600
# dtype: float64
#
# 2026-01-09: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    329.190002
# GS     938.979980
# MS     186.320007
# BAC     55.849998
# C      121.320000
# Name: 2026-01-09 00:00:00, dtype: float64
# JPM    0.398203
# GS    -0.093260
# MS    -1.302724
# BAC    4.883430
# C     -1.162656
# dtype: float64
#
# 2026-01-12: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    324.489990
# GS     949.549988
# MS     186.570007
# BAC     55.189999
# C      117.699997
# Name: 2026-01-12 00:00:00, dtype: float64
# JPM    0.761056
# GS    -0.681218
# MS    -1.606805
# BAC    2.914305
# C      6.726001
# dtype: float64
#
# 2026-01-13: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    310.899994
# GS     938.150024
# MS     182.759995
# BAC     54.540001
# C      116.300003
# Name: 2026-01-13 00:00:00, dtype: float64
# JPM    2.855995
# GS    -0.160184
# MS     0.777952
# BAC   -2.900752
# C     -1.325333
# dtype: float64
#
# 2026-01-14: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    307.869995
# GS     932.669983
# MS     180.779999
# BAC     52.480000
# C      112.410004
# Name: 2026-01-14 00:00:00, dtype: float64
# JPM    -0.724751
# GS     -0.382345
# MS     -1.028534
# BAC    14.002541
# C       5.222797
# dtype: float64
#
# 2026-01-15: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    309.260010
# GS     975.859985
# MS     191.229996
# BAC     52.590000
# C      117.459999
# Name: 2026-01-15 00:00:00, dtype: float64
# JPM     2.329811
# GS     -0.701812
# MS     -5.603143
# BAC    15.247357
# C      -5.434697
# dtype: float64
#
# 2026-01-16: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    312.470001
# GS     962.000000
# MS     189.089996
# BAC     52.970001
# C      118.040001
# Name: 2026-01-16 00:00:00, dtype: float64
# JPM   -1.198459
# GS     0.492312
# MS     1.955084
# BAC   -5.015576
# C     -1.582044
# dtype: float64
#
# 2026-01-19: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    312.470001
# GS     962.000000
# MS     189.089996
# BAC     52.970001
# C      118.040001
# Name: 2026-01-19 00:00:00, dtype: float64
# JPM    0.0
# GS     0.0
# MS     0.0
# BAC    0.0
# C      0.0
# dtype: float64
#
# Error occured here
# 2026-01-20: executing pending target
#  JPM    0.166667
# GS     0.166667
# MS     0.166667
# BAC    0.166667
# C      0.166667
# dtype: float64
#
# Current prices executed at:
# JPM    308.309998
# GS     954.190002
# MS     184.500107
# BAC     52.724998
# C      115.069901
# Name: 2026-01-20 00:00:00, dtype: float64
# JPM    0.081783
# GS    -0.161309
# MS     2.185156
# BAC   -5.203905
# C      3.769804
# dtype: float64

# %%
backtester.plot_pnl_curve()

# %% [markdown]
# # <a id="Strategy3"> __Momentum Based Strategy__ </a>
# In this section we will be backtesting a simple strategy - We include a momentum term and test if it is a significant predictor using WLS.

# %%
import backtesting # To backtest the strategy
import heuristic_pf_construct # To test out the weighted strategies.
import eda_pipeline

from typing import Optional, List, Tuple, Dict
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %%
tickers = "NVDA"
start_date = "2023-01-02"
end_date = "2025-09-30"


data = yf.download(
    tickers=tickers,
    start=start_date,
    end=end_date,          # or use start="2022-01-01", end="2025-11-26"
    interval="1d",
    group_by="ticker",    # organizes returned DataFrame by ticker first
    threads=True,
    auto_adjust=False     # keep Adj Close column rather than auto-adjusting all columns
)

columns_wanted = ["Open", "High", "Low", "Close", "Adj Close", "Volume"]

adj = data[tickers][["Adj Close"]]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ##  <a id="Strategy3EDA"> Checking for Missing Values </a>

# %%
eda_pipeline.missing_and_duplicates(adj)
# Out:
# Total rows: 687, Duplicated rows: 5
# First 5 duplicated rows (by index peek):
# Price        Adj Close
# Date
# 2023-12-28   49.494423
# 2023-12-29   49.494423
# 2024-06-28  123.487152
# 2024-07-22  123.487152
# 2025-01-08  140.071701
#
# Top missing columns:
# Empty DataFrame
# Columns: [missing_count, missing_percentage]
# Index: []

# %% [markdown]
# From the above we conclude that there are no missing values in the data - it is safe to proceed.

# %%
plt.figure(figsize=(15,5))
adj.plot()
plt.title("Price Series of NVDA")
plt.show()

# %% [markdown]
# We now want to include momentum as a regressor, and plot the time series of momentum. For now - we include the following:
#
# 1. weekly momentum
# 2. 30-day momentum

# %%
# Mark for review - !!!! NOTE THAT WE NEED TO CHECK IF THE DATES ARE ALIGNED!!!

adj["7d_momentum"] = adj["Adj Close"] / adj["Adj Close"].shift(7) - 1
adj["30d_momentum"] = adj["Adj Close"] / adj["Adj Close"].shift(30) - 1

# %%
plot_7d_momentum = adj["7d_momentum"].dropna()
plot_30d_momentum = adj["30d_momentum"].dropna()

fig, ax = plt.subplots(nrows=2, figsize=(15,5), sharex = True)
plot_7d_momentum.plot(ax=ax[0])
plot_30d_momentum.plot(ax=ax[1])
plt.show()
