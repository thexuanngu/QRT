# %% [markdown]
# ## Import + Data Preparation + Tickers Choosing

# %%
import sys
sys.path.append(r"/Users/nuts./Desktop/QRT/QRT")
import backtest.backtesting as bt
import backtest.backtest_results as btr
import heuristic_pf_construct # To test out the weighted strategies.
import eda_pipeline 

from typing import Optional, List, Tuple, Dict
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# Recreation of the dataset we are trying to retrieve.
tickers = [
    "JPM",   # JPMorgan (NYSE)
    "GS",    # Goldman Sachs (NYSE)
    "MS",    # Morgan Stanley (NYSE)
    "BAC",   # Bank of America (NYSE)
    "C",     # Citigroup (NYSE)
    "UBS",   # UBS (NYSE / SIX)
    "BARC.L",# Barclays (LSE)
    "HSBA.L",# HSBC (LSE)
    "BNP.PA" # BNP Paribas (Euronext Paris)
]

# What we have: data.columns is ["Open", "High", "Low", "Close", "Adj Close", "Volume"]

data = yf.download(
    tickers=tickers,
    period="3y",          # or use start="2022-01-01", end="2025-11-26"
    interval="1d",
    group_by="ticker",    # organizes returned DataFrame by ticker first
    threads=True,
    auto_adjust=False     # keep Adj Close column rather than auto-adjusting all columns
)

adj = pd.concat({t: data[t]["Adj Close"] for t in tickers}, axis=1)
adj = eda_pipeline.eda_pipeline(adj)
# Out:
# [*********************100%***********************]  9 of 9 completed

# %%
display(data.columns)
# Out:
# MultiIndex([(   'UBS',      'Open'),
#             (   'UBS',      'High'),
#             (   'UBS',       'Low'),
#             (   'UBS',     'Close'),
#             (   'UBS', 'Adj Close'),
#             (   'UBS',    'Volume'),
#             (    'GS',      'Open'),
#             (    'GS',      'High'),
#             (    'GS',       'Low'),
#             (    'GS',     'Close'),
#             (    'GS', 'Adj Close'),
#             (    'GS',    'Volume'),
#             (   'BAC',      'Open'),
#             (   'BAC',      'High'),
#             (   'BAC',       'Low'),
#             (   'BAC',     'Close'),
#             (   'BAC', 'Adj Close'),
#             (   'BAC',    'Volume'),
#             (    'MS',      'Open'),
#             (    'MS',      'High'),
#             (    'MS',       'Low'),
#             (    'MS',     'Close'),
#             (    'MS', 'Adj Close'),
#             (    'MS',    'Volume'),
#             (   'JPM',      'Open'),
#             (   'JPM',      'High'),
#             (   'JPM',       'Low'),
#             (   'JPM',     'Close'),
#             (   'JPM', 'Adj Close'),
#             (   'JPM',    'Volume'),
#             ('BNP.PA',      'Open'),
#             ('BNP.PA',      'High'),
#             ('BNP.PA',       'Low'),
#             ('BNP.PA',     'Close'),
#             ('BNP.PA', 'Adj Close'),
#             ('BNP.PA',    'Volume'),
#             (     'C',      'Open'),
#             (     'C',      'High'),
#             (     'C',       'Low'),
#             (     'C',     'Close'),
#             (     'C', 'Adj Close'),
#             (     'C',    'Volume'),
#             ('BARC.L',      'Open'),
#             ('BARC.L',      'High'),
#             ('BARC.L',       'Low'),
#             ('BARC.L',     'Close'),
#             ('BARC.L', 'Adj Close'),
#             ('BARC.L',    'Volume'),
#             ('HSBA.L',      'Open'),
#             ('HSBA.L',      'High'),
#             ('HSBA.L',       'Low'),
#             ('HSBA.L',     'Close'),
#             ('HSBA.L', 'Adj Close'),
#             ('HSBA.L',    'Volume')],
#            names=['Ticker', 'Price'])

# %% [markdown]
# ## Weighting Strategies

# %%
## Need Fixing, Not Ready


def risk_weighting(
    tradable_assets,
    history,
    nav_history,
    gross_exposure: float = 1.0,
    lookback: int = 20,
    min_risk: float = 1e-8,
):
    """
    Risk weighting (inverse volatility) using OHLCV data.

    Calculates historical volatility from Close prices over the last `lookback` periods.
    Returns (cash, pd.Series(weights, index=tradable_assets)) in the same format as equal_weighting.

    Parameters
    ----------
    tradable_assets : list
        List of assets to include
    history : pd.DataFrame
        MultiIndex columns (asset, field), fields include 'Close'
    nav_history : unused, kept for interface consistency
    gross_exposure : float
        Scaling of the portfolio weights
    lookback : int
        Number of periods to compute historical volatility
    min_risk : float
        Minimum risk floor to avoid divide-by-zero
    """

    n = len(tradable_assets)

    if len(history) < 2:
        # not enough history to compute returns
        return 0.0, pd.Series(data=np.zeros(n), index=tradable_assets)

    # --- extract Close prices for all tradable assets ---
    try:
        close = history.xs("Close", level=1, axis=1)[tradable_assets].astype(float)
    except KeyError:
        raise ValueError("risk_weighting requires 'Close' prices in history for all tradable_assets")

    # --- compute log returns ---
    returns = np.log(close / close.shift(1)).tail(lookback)
    vol = returns.std(ddof=1)

    # --- inverse volatility weighting ---
    safe_vol = vol.clip(lower=min_risk)
    inv_vol = 1.0 / safe_vol
    total_inv = inv_vol.sum()

    if total_inv == 0 or np.isclose(total_inv, 0.0):
        # fallback: equal weighting
        weights = np.ones(n) / n
    else:
        weights = (inv_vol / total_inv) * gross_exposure

    # enforce non-negative weights (long-only)
    weights = weights.clip(lower=0.0)

    # cash = remaining portion to sum to 1 (optional)
    cash = max(0.0, 1.0 - weights.sum())

    return cash, pd.Series(weights, index=tradable_assets)

# %%
def value_weighting(
    tradable_assets,
    history,
    nav_history,
    gross_exposure: float = 1.0,
):
    """
    Market-cap weighting (long-only).
    Uses latest available 'mcap' for each tradable asset.
    Returns (cash, pd.Series(weights, index=tradable_assets))
    """

    n = len(tradable_assets)

    if len(history) == 0:
        return 0.0, pd.Series(data=np.zeros(n), index=tradable_assets)

    # --- extract latest market caps ---
    '''
    try:
        mcap = (
            history
            .iloc[-1]               # latest time
            .loc[tradable_assets]
            .get("mcap")
        )
    except Exception:
        raise ValueError("value_weighting requires 'mcap' in history")
    '''

    #mcap = pd.to_numeric(mcap, errors="coerce").fillna(0.0).values
    last = history.iloc[-1]

    mcap = {}
    for asset in tradable_assets:
        high = last.get((asset, "High"), np.nan)
        low = last.get((asset, "Low"), np.nan)
        volume = last.get((asset, "Volume"), np.nan)

        mid_price = 0.5 * (high + low)
        mcap[asset] = mid_price * volume

    mcap = pd.Series(mcap).fillna(0.0)


    # --- normalize (long-only, self-contained) ---
    mcap[mcap < 0] = 0.0
    total = mcap.sum()

    if total == 0 or np.isclose(total, 0.0):
        # fallback: equal weights
        weights = np.ones(n) / n
    else:
        weights = mcap / total

    # optional gross exposure scaling
    weights *= gross_exposure

    # --- cash handling (kept consistent with your current design) ---
    cash = 1 / n + 1

    return cash, pd.Series(weights, index=tradable_assets)

# %%
def equal_weighting(
    tradable_assets, 
    history, 
    nav_history, 
    #price_col: str = "price",
    #risk_col: str = "risk",
    #mcap_col: str = "mcap",            # unused but kept for identical signature
    #long_only: bool = True,
    gross_exposure: float = 1.0,
) -> pd.DataFrame:
    # With no amount in cash. 
    """
    Equal weighting. If long_only=True returns all weights = 1/N.
    If long_only=False returns centered long-short equal-magnitude weights (gross exposure scaled).
    """
    n = len(tradable_assets)
    if len(history) == 0:
        return 0, pd.Series(data=np.zeros(len(tradable_assets)), index=tradable_assets)
    #if long_only:
    weights = np.ones(n) / (n + 1)
    cash = 1 / n + 1
    #else:
        # initial pattern: +1 for first half, -1 for second half (user may want to pre-sort df by signal)
        #pattern = np.concatenate([np.ones(n // 2), -np.ones(n - n // 2)])
        #weights = _normalize_weights(pattern, long_only=False, gross_exposure=gross_exposure)

    labels_and_weights = pd.Series(data=weights, index=tradable_assets)
    return cash, labels_and_weights

# %% [markdown]
# ## Backtesting Prep

# %%
tradable_assets = [
    "JPM",   # JPMorgan (NYSE)
    "GS",    # Goldman Sachs (NYSE)
    "MS",    # Morgan Stanley (NYSE)
    "BAC",   # Bank of America (NYSE)
    "C",     # Citigroup (NYSE)
]

# Need to wrap the strategy function into a strategy to be compatible with the pipeline
#strategy_name = "equal_weights"
#strategy = equal_weighting

strategy_name = "value_weights"
strategy = value_weighting

#strategy_name = "risk_weights"
#strategy = risk_weighting


backtester = bt.Backtester(tradable_assets=tradable_assets,
                                    data = adj,
                                    strategy_fn=bt.FunctionStrategy(strategy, tradable_assets),
                                    strategy_name=bt.FunctionStrategy(strategy_name, tradable_assets),
                                    allow_short=False,
                                    cash_start=100000,
                                    riskfree_per_period=0.04 / 252)

backtester.run(verbose=True)
# Out:
# 2023-01-30: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    129.586456
# GS     331.518463
# MS      87.405716
# BAC     32.628819
# C       46.402431
# Name: 2023-01-30 00:00:00, dtype: float64
#
# 2023-01-31: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    130.359497
# GS     339.262451
# MS      88.653610
# BAC     32.795193
# C       46.823860
# Name: 2023-01-31 00:00:00, dtype: float64
#
# 2023-02-01: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    130.014908
# GS     339.169800
# MS      89.436928
# BAC     33.201893
# C       46.761097
# Name: 2023-02-01 00:00:00, dtype: float64
#
# 2023-02-02: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    129.409470
# GS     342.656860
# MS      90.366005
# BAC     33.396011
# C       46.823860
# Name: 2023-02-02 00:00:00, dtype: float64
#
# 2023-02-03: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    131.412018
# GS     343.102051
# MS      90.566391
# BAC     33.673306
# C       46.135674
# Name: 2023-02-03 00:00:00, dtype: float64
#
# 2023-02-06: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.185043
# GS     343.890381
# MS      90.083633
# BAC     33.617847
# C       46.054184
# Name: 2023-02-06 00:00:00, dtype: float64
#
# 2023-02-07: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    133.796387
# GS     347.229095
# MS      90.375107
# BAC     33.987583
# C       46.298672
# Name: 2023-02-07 00:00:00, dtype: float64
#
# 2023-02-08: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.855698
# GS     347.878296
# MS      90.138283
# BAC     33.738010
# C       46.316780
# Name: 2023-02-08 00:00:00, dtype: float64
#
# 2023-02-09: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    130.787933
# GS     341.284241
# MS      89.309410
# BAC     33.017040
# C       45.257332
# Name: 2023-02-09 00:00:00, dtype: float64
#
# 2023-02-10: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    131.365433
# GS     344.335541
# MS      89.664635
# BAC     32.887634
# C       45.375050
# Name: 2023-02-10 00:00:00, dtype: float64
#
# 2023-02-13: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.790451
# GS     346.876678
# MS      90.566391
# BAC     32.952335
# C       46.180954
# Name: 2023-02-13 00:00:00, dtype: float64
#
# 2023-02-14: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    133.377228
# GS     344.799286
# MS      91.595650
# BAC     32.924599
# C       46.733311
# Name: 2023-02-14 00:00:00, dtype: float64
#
# 2023-02-15: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    133.936096
# GS     347.173462
# MS      91.841599
# BAC     32.869137
# C       46.923470
# Name: 2023-02-15 00:00:00, dtype: float64
#
# 2023-02-16: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.091904
# GS     343.333954
# MS      90.693916
# BAC     32.610325
# C       46.597488
# Name: 2023-02-16 00:00:00, dtype: float64
#
# 2023-02-17: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.483124
# GS     341.757294
# MS      90.639259
# BAC     32.675034
# C       46.561264
# Name: 2023-02-17 00:00:00, dtype: float64
#
# 2023-02-20: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.483124
# GS     341.757294
# MS      90.639259
# BAC     32.675034
# C       46.561264
# Name: 2023-02-20 00:00:00, dtype: float64
#
# 2023-02-21: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    130.052139
# GS     334.912872
# MS      88.917740
# BAC     31.907846
# C       45.130558
# Name: 2023-02-21 00:00:00, dtype: float64
#
# 2023-02-22: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    129.055511
# GS     334.699554
# MS      88.598938
# BAC     31.695248
# C       45.311668
# Name: 2023-02-22 00:00:00, dtype: float64
#
# 2023-02-23: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    130.089386
# GS     337.157257
# MS      89.209206
# BAC     31.667515
# C       45.619537
# Name: 2023-02-23 00:00:00, dtype: float64
#
# 2023-02-24: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    131.262955
# GS     337.444794
# MS      88.990616
# BAC     31.621292
# C       45.438431
# Name: 2023-02-24 00:00:00, dtype: float64
#
# 2023-02-27: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.408615
# GS     339.002838
# MS      88.079750
# BAC     31.621292
# C       45.701031
# Name: 2023-02-27 00:00:00, dtype: float64
#
# 2023-02-28: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    133.516983
# GS     326.130096
# MS      87.897568
# BAC     31.704487
# C       45.900238
# Name: 2023-02-28 00:00:00, dtype: float64
#
# 2023-03-01: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.771835
# GS     323.402649
# MS      87.615211
# BAC     31.556599
# C       46.633705
# Name: 2023-03-01 00:00:00, dtype: float64
#
# 2023-03-02: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    131.393372
# GS     326.083435
# MS      87.515030
# BAC     31.156559
# C       46.543156
# Name: 2023-03-02 00:00:00, dtype: float64
#
# 2023-03-03: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    133.805710
# GS     333.546631
# MS      89.564445
# BAC     31.779877
# C       47.403389
# Name: 2023-03-03 00:00:00, dtype: float64
#
# 2023-03-06: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    133.023346
# GS     333.509277
# MS      89.609985
# BAC     31.714748
# C       47.249451
# Name: 2023-03-06 00:00:00, dtype: float64
#
# 2023-03-07: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    129.111435
# GS     323.262512
# MS      87.496803
# BAC     30.700697
# C       46.253395
# Name: 2023-03-07 00:00:00, dtype: float64
#
# 2023-03-08: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    128.347656
# GS     326.260834
# MS      87.351067
# BAC     30.291359
# C       45.891190
# Name: 2023-03-08 00:00:00, dtype: float64
#
# 2023-03-09: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    121.399391
# GS     319.535645
# MS      83.980896
# BAC     28.412100
# C       44.007729
# Name: 2023-03-09 00:00:00, dtype: float64
#
# 2023-03-10: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    124.482330
# GS     306.066376
# MS      82.022568
# BAC     28.160913
# C       43.772297
# Name: 2023-03-10 00:00:00, dtype: float64
#
# 2023-03-13: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    122.246948
# GS     294.708069
# MS      80.146210
# BAC     26.523544
# C       40.512463
# Name: 2023-03-13 00:00:00, dtype: float64
#
# 2023-03-14: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    125.385780
# GS     300.910309
# MS      81.949684
# BAC     26.756124
# C       42.921124
# Name: 2023-03-14 00:00:00, dtype: float64
#
# 2023-03-15: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    119.462051
# GS     291.606964
# MS      77.777969
# BAC     26.504936
# C       40.584908
# Name: 2023-03-15 00:00:00, dtype: float64
#
# 2023-03-16: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    121.781258
# GS     294.315735
# MS      79.253563
# BAC     26.951490
# C       41.309315
# Name: 2023-03-16 00:00:00, dtype: float64
#
# 2023-03-17: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    117.180107
# GS     283.527252
# MS      76.675835
# BAC     25.881617
# C       40.068764
# Name: 2023-03-17 00:00:00, dtype: float64
#
# 2023-03-20: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    118.418900
# GS     289.122314
# MS      78.005699
# BAC     25.816494
# C       39.923889
# Name: 2023-03-20 00:00:00, dtype: float64
#
# 2023-03-21: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    121.594978
# GS     296.361328
# MS      80.847565
# BAC     26.597967
# C       40.811279
# Name: 2023-03-21 00:00:00, dtype: float64
#
# 2023-03-22: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    118.456139
# GS     292.989349
# MS      79.745422
# BAC     25.714161
# C       39.579792
# Name: 2023-03-22 00:00:00, dtype: float64
#
# 2023-03-23: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    118.139450
# GS     294.091553
# MS      78.187851
# BAC     25.090843
# C       39.344364
# Name: 2023-03-23 00:00:00, dtype: float64
#
# 2023-03-24: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    116.341858
# GS     291.961914
# MS      76.466347
# BAC     25.249001
# C       39.036488
# Name: 2023-03-24 00:00:00, dtype: float64
#
# 2023-03-27: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    119.676300
# GS     297.528961
# MS      77.094833
# BAC     26.504936
# C       40.548687
# Name: 2023-03-27 00:00:00, dtype: float64
#
# 2023-03-28: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    120.039543
# GS     297.444885
# MS      77.313431
# BAC     26.160715
# C       40.947113
# Name: 2023-03-28 00:00:00, dtype: float64
#
# 2023-03-29: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    120.281685
# GS     299.574554
# MS      78.552200
# BAC     26.672394
# C       41.608139
# Name: 2023-03-29 00:00:00, dtype: float64
#
# 2023-03-30: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    119.918434
# GS     299.966858
# MS      78.433800
# BAC     26.328176
# C       41.716793
# Name: 2023-03-30 00:00:00, dtype: float64
#
# 2023-03-31: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    121.371437
# GS     305.543213
# MS      79.973137
# BAC     26.607269
# C       42.459309
# Name: 2023-03-31 00:00:00, dtype: float64
#
# 2023-04-03: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    121.231728
# GS     304.992126
# MS      79.390190
# BAC     26.597967
# C       42.296318
# Name: 2023-04-03 00:00:00, dtype: float64
#
# 2023-04-04: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    119.611084
# GS     301.377289
# MS      77.258781
# BAC     26.030474
# C       41.734909
# Name: 2023-04-04 00:00:00, dtype: float64
#
# 2023-04-05: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    119.789436
# GS     300.331116
# MS      76.347931
# BAC     25.714161
# C       41.445137
# Name: 2023-04-05 00:00:00, dtype: float64
#
# 2023-04-06: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    119.658028
# GS     301.143799
# MS      76.684944
# BAC     25.900223
# C       41.526634
# Name: 2023-04-06 00:00:00, dtype: float64
#
# 2023-04-10: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    120.052284
# GS     303.535004
# MS      76.511879
# BAC     25.993259
# C       42.124275
# Name: 2023-04-10 00:00:00, dtype: float64
#
# 2023-04-11: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    120.643669
# GS     305.786072
# MS      77.504715
# BAC     26.709604
# C       42.740021
# Name: 2023-04-11 00:00:00, dtype: float64
#
# 2023-04-12: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    120.624901
# GS     308.466888
# MS      77.850838
# BAC     26.495634
# C       42.486473
# Name: 2023-04-12 00:00:00, dtype: float64
#
# 2023-04-13: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    121.084862
# GS     310.232269
# MS      78.051239
# BAC     26.570057
# C       42.830570
# Name: 2023-04-13 00:00:00, dtype: float64
#
# 2023-04-14: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    130.227951
# GS     314.706451
# MS      78.980301
# BAC     27.463173
# C       44.877026
# Name: 2023-04-14 00:00:00, dtype: float64
#
# 2023-04-17: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    131.260559
# GS     317.284454
# MS      81.330299
# BAC     28.253948
# C       44.994728
# Name: 2023-04-17 00:00:00, dtype: float64
#
# 2023-04-18: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.734329
# GS     311.894958
# MS      81.840385
# BAC     28.430706
# C       45.347889
# Name: 2023-04-18 00:00:00, dtype: float64
#
# 2023-04-19: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.565338
# GS     314.678436
# MS      82.386909
# BAC     27.965546
# C       45.637650
# Name: 2023-04-19 00:00:00, dtype: float64
#
# 2023-04-20: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.180481
# GS     316.378448
# MS      82.368690
# BAC     27.816692
# C       44.732140
# Name: 2023-04-20 00:00:00, dtype: float64
#
# 2023-04-21: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    131.927002
# GS     319.133942
# MS      82.997192
# BAC     27.788786
# C       44.397095
# Name: 2023-04-21 00:00:00, dtype: float64
#
# 2023-04-24: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.105408
# GS     321.282257
# MS      82.159180
# BAC     27.686449
# C       44.397095
# Name: 2023-04-24 00:00:00, dtype: float64
#
# 2023-04-25: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    129.232910
# GS     317.097687
# MS      80.209961
# BAC     26.830547
# C       43.373871
# Name: 2023-04-25 00:00:00, dtype: float64
#
# 2023-04-26: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    126.942467
# GS     314.370117
# MS      80.556091
# BAC     26.458418
# C       42.432148
# Name: 2023-04-26 00:00:00, dtype: float64
#
# 2023-04-27: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    128.650909
# GS     319.077942
# MS      82.213837
# BAC     26.877064
# C       42.586082
# Name: 2023-04-27 00:00:00, dtype: float64
#
# 2023-04-28: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    129.767975
# GS     320.796600
# MS      82.659424
# BAC     27.239895
# C       43.089569
# Name: 2023-04-28 00:00:00, dtype: float64
#
# 2023-05-01: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.546570
# GS     318.115814
# MS      80.785194
# BAC     27.016619
# C       43.254353
# Name: 2023-05-01 00:00:00, dtype: float64
#
# 2023-05-02: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    130.406326
# GS     311.390533
# MS      79.278458
# BAC     26.197927
# C       42.110058
# Name: 2023-05-02 00:00:00, dtype: float64
#
# 2023-05-03: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    127.646477
# GS     306.981659
# MS      77.863579
# BAC     25.918835
# C       41.807964
# Name: 2023-05-03 00:00:00, dtype: float64
#
# 2023-05-04: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    125.900475
# GS     300.078888
# MS      75.897476
# BAC     25.109453
# C       41.103069
# Name: 2023-05-04 00:00:00, dtype: float64
#
# 2023-05-05: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    128.359894
# GS     305.459167
# MS      77.983017
# BAC     25.779282
# C       42.403000
# Name: 2023-05-05 00:00:00, dtype: float64
#
# 2023-05-08: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    128.669678
# GS     304.982819
# MS      77.569603
# BAC     25.760675
# C       42.439613
# Name: 2023-05-08 00:00:00, dtype: float64
#
# 2023-05-09: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    128.050140
# GS     303.357513
# MS      77.514481
# BAC     25.732767
# C       42.586086
# Name: 2023-05-09 00:00:00, dtype: float64
#
# 2023-05-10: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    128.115860
# GS     301.283905
# MS      76.917282
# BAC     25.416454
# C       42.448765
# Name: 2023-05-10 00:00:00, dtype: float64
#
# 2023-05-11: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    127.712212
# GS     299.574554
# MS      75.915855
# BAC     25.481577
# C       42.137516
# Name: 2023-05-11 00:00:00, dtype: float64
#
# 2023-05-12: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    125.881699
# GS     298.434937
# MS      75.695351
# BAC     25.202482
# C       41.606567
# Name: 2023-05-12 00:00:00, dtype: float64
#
# 2023-05-15: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    126.942467
# GS     300.835510
# MS      76.209846
# BAC     25.723463
# C       42.155830
# Name: 2023-05-15 00:00:00, dtype: float64
#
# 2023-05-16: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    126.088234
# GS     299.658569
# MS      75.208420
# BAC     25.453669
# C       41.450939
# Name: 2023-05-16 00:00:00, dtype: float64
#
# 2023-05-17: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    129.965118
# GS     308.410828
# MS      77.091850
# BAC     26.579361
# C       43.098732
# Name: 2023-05-17 00:00:00, dtype: float64
#
# 2023-05-18: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    130.950760
# GS     307.850342
# MS      77.624710
# BAC     26.486326
# C       42.467072
# Name: 2023-05-18 00:00:00, dtype: float64
#
# 2023-05-19: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    130.650375
# GS     304.646515
# MS      75.557533
# BAC     26.151413
# C       41.844578
# Name: 2023-05-19 00:00:00, dtype: float64
#
# 2023-05-22: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    129.570847
# GS     303.497681
# MS      75.585098
# BAC     26.365389
# C       41.917816
# Name: 2023-05-22 00:00:00, dtype: float64
#
# 2023-05-23: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    128.219116
# GS     302.236664
# MS      75.925034
# BAC     26.588665
# C       42.027664
# Name: 2023-05-23 00:00:00, dtype: float64
#
# 2023-05-24: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    127.045677
# GS     298.724579
# MS      74.620415
# BAC     26.142109
# C       40.727749
# Name: 2023-05-24 00:00:00, dtype: float64
#
# 2023-05-25: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    127.355492
# GS     302.526184
# MS      76.255783
# BAC     26.207235
# C       40.489735
# Name: 2023-05-25 00:00:00, dtype: float64
#
# 2023-05-26: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    128.547638
# GS     310.120178
# MS      77.082657
# BAC     26.337477
# C       40.828445
# Name: 2023-05-26 00:00:00, dtype: float64
#
# 2023-05-29: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    128.547638
# GS     310.120178
# MS      77.082657
# BAC     26.337477
# C       40.828445
# Name: 2023-05-29 00:00:00, dtype: float64
#
# 2023-05-30: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    129.035782
# GS     309.017944
# MS      76.641655
# BAC     26.290962
# C       40.919987
# Name: 2023-05-30 00:00:00, dtype: float64
#
# 2023-05-31: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    127.393051
# GS     304.848511
# MS      75.116547
# BAC     25.853706
# C       40.572117
# Name: 2023-05-31 00:00:00, dtype: float64
#
# 2023-06-01: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    129.148438
# GS     297.789642
# MS      75.401352
# BAC     26.050636
# C       41.048153
# Name: 2023-06-01 00:00:00, dtype: float64
#
# 2023-06-02: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    131.861313
# GS     304.613251
# MS      77.496094
# BAC     26.922739
# C       42.403000
# Name: 2023-06-02 00:00:00, dtype: float64
#
# 2023-06-05: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    130.565872
# GS     302.881470
# MS      76.935654
# BAC     26.763325
# C       42.329762
# Name: 2023-06-05 00:00:00, dtype: float64
#
# 2023-06-06: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    130.800552
# GS     307.577972
# MS      78.883408
# BAC     27.410370
# C       43.226887
# Name: 2023-06-06 00:00:00, dtype: float64
#
# 2023-06-07: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.067841
# GS     316.001587
# MS      79.471390
# BAC     27.644808
# C       43.950081
# Name: 2023-06-07 00:00:00, dtype: float64
#
# 2023-06-08: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.105408
# GS     315.738007
# MS      79.296829
# BAC     27.410370
# C       44.032471
# Name: 2023-06-08 00:00:00, dtype: float64
#
# 2023-06-09: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.368225
# GS     316.255676
# MS      79.204956
# BAC     27.447880
# C       44.215553
# Name: 2023-06-09 00:00:00, dtype: float64
#
# 2023-06-12: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.358826
# GS     319.521484
# MS      80.335014
# BAC     27.316597
# C       44.352875
# Name: 2023-06-12 00:00:00, dtype: float64
#
# 2023-06-13: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    133.316330
# GS     322.354492
# MS      81.106758
# BAC     27.569788
# C       44.572578
# Name: 2023-06-13 00:00:00, dtype: float64
#
# 2023-06-14: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    132.818802
# GS     318.514526
# MS      80.831131
# BAC     27.307220
# C       44.160637
# Name: 2023-06-14 00:00:00, dtype: float64
#
# 2023-06-15: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    134.320755
# GS     319.756866
# MS      81.814186
# BAC     27.541656
# C       44.453568
# Name: 2023-06-15 00:00:00, dtype: float64
#
# 2023-06-16: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    134.480331
# GS     318.410919
# MS      80.932190
# BAC     27.372862
# C       44.114864
# Name: 2023-06-16 00:00:00, dtype: float64
#
# 2023-06-19: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    134.480331
# GS     318.410919
# MS      80.932190
# BAC     27.372862
# C       44.114864
# Name: 2023-06-19 00:00:00, dtype: float64
#
# 2023-06-20: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    133.795074
# GS     311.267426
# MS      79.682716
# BAC     27.072779
# C       43.583908
# Name: 2023-06-20 00:00:00, dtype: float64
#
# 2023-06-21: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    133.597946
# GS     305.949768
# MS      79.324387
# BAC     26.791456
# C       43.400822
# Name: 2023-06-21 00:00:00, dtype: float64
#
# 2023-06-22: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    131.025864
# GS     300.782654
# MS      77.633904
# BAC     26.219427
# C       42.686783
# Name: 2023-06-22 00:00:00, dtype: float64
#
# 2023-06-23: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    130.340607
# GS     296.199127
# MS      76.788666
# BAC     26.022501
# C       42.128368
# Name: 2023-06-23 00:00:00, dtype: float64
#
# 2023-06-26: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    130.659744
# GS     293.987274
# MS      76.797844
# BAC     26.341335
# C       42.329762
# Name: 2023-06-26 00:00:00, dtype: float64
#
# 2023-06-27: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    130.669128
# GS     295.013245
# MS      77.569603
# BAC     26.482002
# C       42.476234
# Name: 2023-06-27 00:00:00, dtype: float64
#
# 2023-06-28: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    130.096527
# GS     295.210876
# MS      77.165344
# BAC     26.322582
# C       42.320602
# Name: 2023-06-28 00:00:00, dtype: float64
#
# 2023-06-29: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    134.639923
# GS     304.086212
# MS      78.313766
# BAC     26.875854
# C       42.375530
# Name: 2023-06-29 00:00:00, dtype: float64
#
# 2023-06-30: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    136.526733
# GS     303.568542
# MS      78.460754
# BAC     26.903988
# C       42.146675
# Name: 2023-06-30 00:00:00, dtype: float64
#
# 2023-07-03: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    137.625046
# GS     307.399139
# MS      79.388702
# BAC     27.382238
# C       42.787479
# Name: 2023-07-03 00:00:00, dtype: float64
#
# 2023-07-04: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    137.625046
# GS     307.399139
# MS      79.388702
# BAC     27.382238
# C       42.787479
# Name: 2023-07-04 00:00:00, dtype: float64
#
# 2023-07-05: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    136.708206
# GS     301.224976
# MS      78.938499
# BAC     27.269712
# C       42.842411
# Name: 2023-07-05 00:00:00, dtype: float64
#
# 2023-07-06: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    135.356644
# GS     294.589691
# MS      76.558968
# BAC     26.519514
# C       41.542488
# Name: 2023-07-06 00:00:00, dtype: float64
#
# 2023-07-07: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    136.424652
# GS     296.632080
# MS      76.586533
# BAC     26.753946
# C       41.872040
# Name: 2023-07-07 00:00:00, dtype: float64
#
# 2023-07-10: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    137.190247
# GS     297.855560
# MS      76.623299
# BAC     26.875854
# C       41.807964
# Name: 2023-07-10 00:00:00, dtype: float64
#
# 2023-07-11: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    139.335754
# GS     302.006195
# MS      78.056519
# BAC     27.213444
# C       42.595242
# Name: 2023-07-11 00:00:00, dtype: float64
#
# 2023-07-12: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    140.025726
# GS     307.201508
# MS      78.800697
# BAC     27.532278
# C       43.373363
# Name: 2023-07-12 00:00:00, dtype: float64
#
# 2023-07-13: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    140.706223
# GS     309.347412
# MS      79.204956
# BAC     27.822979
# C       43.647991
# Name: 2023-07-13 00:00:00, dtype: float64
#
# 2023-07-14: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    141.556870
# GS     307.003845
# MS      78.809883
# BAC     27.297840
# C       41.881199
# Name: 2023-07-14 00:00:00, dtype: float64
#
# 2023-07-17: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    144.968933
# GS     307.954529
# MS      79.351944
# BAC     27.569788
# C       42.348064
# Name: 2023-07-17 00:00:00, dtype: float64
#
# 2023-07-18: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    145.233597
# GS     317.432098
# MS      84.469368
# BAC     28.788858
# C       43.043797
# Name: 2023-07-18 00:00:00, dtype: float64
#
# 2023-07-19: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    145.791214
# GS     320.519196
# MS      85.590233
# BAC     29.567188
# C       43.501522
# Name: 2023-07-19 00:00:00, dtype: float64
#
# 2023-07-20: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    147.587051
# GS     330.222809
# MS      86.178223
# BAC     29.717232
# C       43.400822
# Name: 2023-07-20 00:00:00, dtype: float64
#
# 2023-07-21: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    146.452820
# GS     331.258026
# MS      86.371155
# BAC     29.989178
# C       43.071262
# Name: 2023-07-21 00:00:00, dtype: float64
#
# 2023-07-24: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    149.335571
# GS     337.818146
# MS      86.977524
# BAC     30.617472
# C       43.629681
# Name: 2023-07-24 00:00:00, dtype: float64
#
# 2023-07-25: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    148.220291
# GS     333.836945
# MS      86.747841
# BAC     30.148600
# C       43.107880
# Name: 2023-07-25 00:00:00, dtype: float64
#
# 2023-07-26: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    149.108734
# GS     336.528687
# MS      85.939354
# BAC     30.392405
# C       43.474056
# Name: 2023-07-26 00:00:00, dtype: float64
#
# 2023-07-27: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    147.464142
# GS     333.658081
# MS      85.213539
# BAC     29.961048
# C       43.831074
# Name: 2023-07-27 00:00:00, dtype: float64
#
# 2023-07-28: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    148.305344
# GS     332.453339
# MS      84.907555
# BAC     29.914154
# C       43.400822
# Name: 2023-07-28 00:00:00, dtype: float64
#
# 2023-07-31: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    149.297775
# GS     334.938110
# MS      84.898270
# BAC     30.007933
# C       43.629681
# Name: 2023-07-31 00:00:00, dtype: float64
#
# 2023-08-01: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    148.560547
# GS     336.679321
# MS      84.323387
# BAC     29.651588
# C       43.089569
# Name: 2023-08-01 00:00:00, dtype: float64
#
# 2023-08-02: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    146.878159
# GS     330.448608
# MS      82.821259
# BAC     29.248354
# C       42.393841
# Name: 2023-08-02 00:00:00, dtype: float64
#
# 2023-08-03: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    147.776093
# GS     332.387451
# MS      82.654358
# BAC     29.454662
# C       42.302296
# Name: 2023-08-03 00:00:00, dtype: float64
#
# 2023-08-04: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    147.464142
# GS     332.444000
# MS      82.329819
# BAC     29.351507
# C       42.330074
# Name: 2023-08-04 00:00:00, dtype: float64
#
# 2023-08-07: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    148.163574
# GS     334.646362
# MS      82.598717
# BAC     29.895401
# C       42.441204
# Name: 2023-08-07 00:00:00, dtype: float64
#
# 2023-08-08: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    147.331863
# GS     327.775726
# MS      82.033096
# BAC     29.323378
# C       41.820747
# Name: 2023-08-08 00:00:00, dtype: float64
#
# 2023-08-09: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    145.356430
# GS     322.533356
# MS      81.189301
# BAC     28.938900
# C       41.153992
# Name: 2023-08-09 00:00:00, dtype: float64
#
# 2023-08-10: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    145.139038
# GS     320.378021
# MS      81.263489
# BAC     29.013918
# C       41.061382
# Name: 2023-08-10 00:00:00, dtype: float64
#
# 2023-08-11: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    145.980240
# GS     320.688568
# MS      81.319130
# BAC     29.342131
# C       41.274376
# Name: 2023-08-11 00:00:00, dtype: float64
#
# 2023-08-14: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    146.282700
# GS     317.874481
# MS      80.976028
# BAC     29.004541
# C       40.839127
# Name: 2023-08-14 00:00:00, dtype: float64
#
# 2023-08-15: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    142.558762
# GS     312.669769
# MS      79.891182
# BAC     28.076174
# C       40.014931
# Name: 2023-08-15 00:00:00, dtype: float64
#
# 2023-08-16: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    141.953888
# GS     309.752075
# MS      79.733521
# BAC     27.466639
# C       39.487083
# Name: 2023-08-16 00:00:00, dtype: float64
#
# 2023-08-17: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    140.479416
# GS     308.255615
# MS      79.548088
# BAC     27.457260
# C       39.320393
# Name: 2023-08-17 00:00:00, dtype: float64
#
# 2023-08-18: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    140.800766
# GS     305.817963
# MS      78.713577
# BAC     27.297840
# C       39.125923
# Name: 2023-08-18 00:00:00, dtype: float64
#
# 2023-08-21: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    141.282776
# GS     303.116791
# MS      78.120132
# BAC     27.335350
# C       38.959229
# Name: 2023-08-21 00:00:00, dtype: float64
#
# 2023-08-22: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    138.352798
# GS     300.039124
# MS      76.942543
# BAC     26.669548
# C       37.986874
# Name: 2023-08-22 00:00:00, dtype: float64
#
# 2023-08-23: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    139.288513
# GS     303.370880
# MS      77.322708
# BAC     26.678928
# C       38.042431
# Name: 2023-08-23 00:00:00, dtype: float64
#
# 2023-08-24: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    139.156174
# GS     301.140289
# MS      77.369080
# BAC     26.838343
# C       38.042431
# Name: 2023-08-24 00:00:00, dtype: float64
#
# 2023-08-25: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    138.986084
# GS     301.319092
# MS      77.165077
# BAC     26.725815
# C       38.190605
# Name: 2023-08-25 00:00:00, dtype: float64
#
# 2023-08-28: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    139.468094
# GS     306.796783
# MS      78.240685
# BAC     26.969629
# C       38.264690
# Name: 2023-08-28 00:00:00, dtype: float64
#
# 2023-08-29: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    140.602264
# GS     312.989716
# MS      79.325554
# BAC     27.354109
# C       38.635113
# Name: 2023-08-29 00:00:00, dtype: float64
#
# 2023-08-30: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    140.035187
# GS     311.831970
# MS      79.056656
# BAC     27.232203
# C       38.310986
# Name: 2023-08-30 00:00:00, dtype: float64
#
# 2023-08-31: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    138.305527
# GS     311.006287
# MS      78.954651
# BAC     27.109276
# C       38.236904
# Name: 2023-08-31 00:00:00, dtype: float64
#
# 2023-09-01: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    138.768692
# GS     310.712097
# MS      79.511009
# BAC     27.402399
# C       38.514721
# Name: 2023-09-01 00:00:00, dtype: float64
#
# 2023-09-04: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    138.768692
# GS     310.712097
# MS      79.511009
# BAC     27.402399
# C       38.514721
# Name: 2023-09-04 00:00:00, dtype: float64
#
# 2023-09-05: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    137.237503
# GS     307.248138
# MS      78.667206
# BAC     27.090364
# C       38.301731
# Name: 2023-09-05 00:00:00, dtype: float64
#
# 2023-09-06: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    137.010681
# GS     304.761688
# MS      78.036697
# BAC     26.844519
# C       38.310986
# Name: 2023-09-06 00:00:00, dtype: float64
#
# 2023-09-07: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    135.838638
# GS     305.549347
# MS      77.739960
# BAC     26.598671
# C       37.718315
# Name: 2023-09-07 00:00:00, dtype: float64
#
# 2023-09-08: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    135.942657
# GS     308.927917
# MS      78.741394
# BAC     26.816149
# C       37.588661
# Name: 2023-09-08 00:00:00, dtype: float64
#
# 2023-09-11: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    136.538086
# GS     308.102234
# MS      77.433975
# BAC     26.929621
# C       37.588661
# Name: 2023-09-11 00:00:00, dtype: float64
#
# 2023-09-12: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    138.314972
# GS     314.033722
# MS      79.325554
# BAC     27.392944
# C       38.598068
# Name: 2023-09-12 00:00:00, dtype: float64
#
# 2023-09-13: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    138.381149
# GS     317.905762
# MS      80.901871
# BAC     27.307844
# C       39.237045
# Name: 2023-09-13 00:00:00, dtype: float64
#
# 2023-09-14: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    141.065414
# GS     327.006927
# MS      82.589447
# BAC     27.610424
# C       39.950111
# Name: 2023-09-14 00:00:00, dtype: float64
#
# 2023-09-15: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    140.649536
# GS     325.080414
# MS      81.977470
# BAC     27.270021
# C       39.551907
# Name: 2023-09-15 00:00:00, dtype: float64
#
# 2023-09-18: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    140.942551
# GS     325.820618
# MS      82.255630
# BAC     27.194376
# C       39.487083
# Name: 2023-09-18 00:00:00, dtype: float64
#
# 2023-09-19: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    140.762955
# GS     324.463562
# MS      82.070190
# BAC     27.090364
# C       39.524120
# Name: 2023-09-19 00:00:00, dtype: float64
#
# 2023-09-20: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    140.167511
# GS     319.538055
# MS      80.799866
# BAC     26.995811
# C       39.172218
# Name: 2023-09-20 00:00:00, dtype: float64
#
# 2023-09-21: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    139.071121
# GS     313.407318
# MS      78.704292
# BAC     26.523026
# C       38.625851
# Name: 2023-09-21 00:00:00, dtype: float64
#
# 2023-09-22: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    137.738419
# GS     311.177155
# MS      77.229988
# BAC     26.135345
# C       37.894264
# Name: 2023-09-22 00:00:00, dtype: float64
#
# 2023-09-25: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    138.418961
# GS     312.078705
# MS      76.988907
# BAC     26.097523
# C       37.986874
# Name: 2023-09-25 00:00:00, dtype: float64
#
# 2023-09-26: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    136.982300
# GS     307.314575
# MS      76.191475
# BAC     25.690933
# C       37.246021
# Name: 2023-09-26 00:00:00, dtype: float64
#
# 2023-09-27: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    137.785721
# GS     305.539856
# MS      75.709305
# BAC     25.785488
# C       37.468277
# Name: 2023-09-27 00:00:00, dtype: float64
#
# 2023-09-28: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    139.496445
# GS     308.624268
# MS      76.210030
# BAC     26.059700
# C       38.153557
# Name: 2023-09-28 00:00:00, dtype: float64
#
# 2023-09-29: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    137.067398
# GS     307.077271
# MS      75.727852
# BAC     25.889500
# C       38.088741
# Name: 2023-09-29 00:00:00, dtype: float64
#
# 2023-10-02: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    135.885925
# GS     302.265778
# MS      74.559525
# BAC     25.246523
# C       37.505322
# Name: 2023-10-02 00:00:00, dtype: float64
#
# 2023-10-03: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    134.884033
# GS     290.516724
# MS      72.343430
# BAC     24.499525
# C       36.912643
# Name: 2023-10-03 00:00:00, dtype: float64
#
# 2023-10-04: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    135.488983
# GS     292.870392
# MS      73.335564
# BAC     24.527893
# C       36.866341
# Name: 2023-10-04 00:00:00, dtype: float64
#
# 2023-10-05: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    136.060226
# GS     294.673492
# MS      73.391205
# BAC     24.641357
# C       36.931168
# Name: 2023-10-05 00:00:00, dtype: float64
#
# 2023-10-06: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# ...
# GS     781.645020
# MS     163.649994
# BAC     53.283104
# C      101.610001
# Name: 2025-11-03 00:00:00, dtype: float64
#
# 2025-11-04: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    307.861328
# GS     786.928833
# MS     164.009995
# BAC     53.263206
# C      101.010002
# Name: 2025-11-04 00:00:00, dtype: float64
#
# 2025-11-05: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    310.280396
# GS     789.177673
# MS     165.179993
# BAC     52.178841
# C      101.690002
# Name: 2025-11-05 00:00:00, dtype: float64
#
# 2025-11-06: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    312.012604
# GS     783.694824
# MS     163.419998
# BAC     53.014500
# C      100.849998
# Name: 2025-11-06 00:00:00, dtype: float64
#
# 2025-11-07: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    312.799042
# GS     782.460938
# MS     162.360001
# BAC     52.924965
# C      100.790001
# Name: 2025-11-07 00:00:00, dtype: float64
#
# 2025-11-10: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    315.467010
# GS     793.267395
# MS     165.050003
# BAC     53.143826
# C      101.489998
# Name: 2025-11-10 00:00:00, dtype: float64
#
# 2025-11-11: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    314.202698
# GS     806.312683
# MS     166.500000
# BAC     53.352741
# C      100.760002
# Name: 2025-11-11 00:00:00, dtype: float64
#
# 2025-11-12: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    318.971191
# GS     834.831299
# MS     169.919998
# BAC     53.830257
# C      102.870003
# Name: 2025-11-12 00:00:00, dtype: float64
#
# 2025-11-13: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    308.090302
# GS     801.526428
# MS     165.610001
# BAC     52.596668
# C      100.669998
# Name: 2025-11-13 00:00:00, dtype: float64
#
# 2025-11-14: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    302.246613
# GS     787.008362
# MS     163.860001
# BAC     52.338013
# C      100.300003
# Name: 2025-11-14 00:00:00, dtype: float64
#
# 2025-11-17: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    299.021179
# GS     771.734131
# MS     159.449997
# BAC     51.213856
# C       98.190002
# Name: 2025-11-17 00:00:00, dtype: float64
#
# 2025-11-18: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    298.065491
# GS     772.470459
# MS     159.830002
# BAC     51.373028
# C       98.320000
# Name: 2025-11-18 00:00:00, dtype: float64
#
# 2025-11-19: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    301.908142
# GS     782.112671
# MS     162.289993
# BAC     51.751064
# C       99.830002
# Name: 2025-11-19 00:00:00, dtype: float64
#
# 2025-11-20: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    297.040131
# GS     769.883301
# MS     158.699997
# BAC     50.736336
# C       97.629997
# Name: 2025-11-20 00:00:00, dtype: float64
#
# 2025-11-21: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    296.681732
# GS     770.211670
# MS     158.169998
# BAC     51.293442
# C       98.699997
# Name: 2025-11-21 00:00:00, dtype: float64
#
# 2025-11-24: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    296.661835
# GS     786.809387
# MS     162.830002
# BAC     51.661530
# C       99.690002
# Name: 2025-11-24 00:00:00, dtype: float64
#
# 2025-11-25: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    301.639374
# GS     798.362122
# MS     165.429993
# BAC     52.208683
# C      101.169998
# Name: 2025-11-25 00:00:00, dtype: float64
#
# 2025-11-26: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    306.258545
# GS     811.984558
# MS     167.940002
# BAC     52.716049
# C      102.500000
# Name: 2025-11-26 00:00:00, dtype: float64
#
# 2025-11-27: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    306.258545
# GS     811.984558
# MS     167.940002
# BAC     52.716049
# C      102.500000
# Name: 2025-11-27 00:00:00, dtype: float64
#
# 2025-11-28: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    311.674103
# GS     821.965088
# MS     169.660004
# BAC     53.372639
# C      103.599998
# Name: 2025-11-28 00:00:00, dtype: float64
#
# 2025-12-01: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    307.532806
# GS     806.859985
# MS     168.470001
# BAC     52.964756
# C      102.680000
# Name: 2025-12-01 00:00:00, dtype: float64
#
# 2025-12-02: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    306.497467
# GS     815.210022
# MS     169.089996
# BAC     52.915012
# C      103.190002
# Name: 2025-12-02 00:00:00, dtype: float64
#
# 2025-12-03: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    310.728394
# GS     836.570007
# MS     173.720001
# BAC     53.810364
# C      106.720001
# Name: 2025-12-03 00:00:00, dtype: float64
#
# 2025-12-04: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    314.680573
# GS     837.830017
# MS     174.889999
# BAC     53.880001
# C      107.790001
# Name: 2025-12-04 00:00:00, dtype: float64
#
# 2025-12-05: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    313.625336
# GS     854.559998
# MS     176.509995
# BAC     53.950001
# C      108.879997
# Name: 2025-12-05 00:00:00, dtype: float64
#
# 2025-12-08: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    313.794556
# GS     866.690002
# MS     176.830002
# BAC     53.900002
# C      108.919998
# Name: 2025-12-08 00:00:00, dtype: float64
#
# 2025-12-09: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    299.160583
# GS     876.580017
# MS     178.830002
# BAC     53.540001
# C      109.430000
# Name: 2025-12-09 00:00:00, dtype: float64
#
# 2025-12-10: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    308.717438
# GS     889.239990
# MS     179.710007
# BAC     54.080002
# C      111.089996
# Name: 2025-12-10 00:00:00, dtype: float64
#
# 2025-12-11: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    315.954803
# GS     911.030029
# MS     180.289993
# BAC     54.560001
# C      111.739998
# Name: 2025-12-11 00:00:00, dtype: float64
#
# 2025-12-12: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    317.089691
# GS     887.960022
# MS     178.410004
# BAC     55.139999
# C      111.800003
# Name: 2025-12-12 00:00:00, dtype: float64
#
# 2025-12-15: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    318.582947
# GS     889.590027
# MS     177.789993
# BAC     55.330002
# C      112.800003
# Name: 2025-12-15 00:00:00, dtype: float64
#
# 2025-12-16: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    314.133026
# GS     879.150024
# MS     176.509995
# BAC     54.810001
# C      111.279999
# Name: 2025-12-16 00:00:00, dtype: float64
#
# 2025-12-17: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    313.565582
# GS     872.330017
# MS     174.800003
# BAC     54.549999
# C      111.459999
# Name: 2025-12-17 00:00:00, dtype: float64
#
# 2025-12-18: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    311.594482
# GS     876.299988
# MS     172.960007
# BAC     54.259998
# C      112.830002
# Name: 2025-12-18 00:00:00, dtype: float64
#
# 2025-12-19: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    315.785553
# GS     893.479980
# MS     176.979996
# BAC     55.270000
# C      114.860001
# Name: 2025-12-19 00:00:00, dtype: float64
#
# 2025-12-22: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    321.639160
# GS     899.000000
# MS     179.759995
# BAC     55.880001
# C      118.089996
# Name: 2025-12-22 00:00:00, dtype: float64
#
# 2025-12-23: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    324.466400
# GS     901.710022
# MS     179.500000
# BAC     55.970001
# C      119.400002
# Name: 2025-12-23 00:00:00, dtype: float64
#
# 2025-12-24: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    327.691864
# GS     910.780029
# MS     181.649994
# BAC     56.250000
# C      121.559998
# Name: 2025-12-24 00:00:00, dtype: float64
#
# 2025-12-26: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    326.437531
# GS     907.039978
# MS     181.869995
# BAC     56.169998
# C      120.419998
# Name: 2025-12-26 00:00:00, dtype: float64
#
# 2025-12-29: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    322.296204
# GS     892.179993
# MS     179.940002
# BAC     55.349998
# C      118.129997
# Name: 2025-12-29 00:00:00, dtype: float64
#
# 2025-12-30: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    321.967712
# GS     884.419983
# MS     179.080002
# BAC     55.279999
# C      117.209999
# Name: 2025-12-30 00:00:00, dtype: float64
#
# 2025-12-31: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    320.773071
# GS     879.000000
# MS     177.529999
# BAC     55.000000
# C      116.690002
# Name: 2025-12-31 00:00:00, dtype: float64
#
# 2026-01-02: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    324.018433
# GS     914.340027
# MS     181.899994
# BAC     55.950001
# C      118.699997
# Name: 2026-01-02 00:00:00, dtype: float64
#
# 2026-01-05: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    332.540009
# GS     948.440002
# MS     186.539993
# BAC     56.889999
# C      123.300003
# Name: 2026-01-05 00:00:00, dtype: float64
#
# 2026-01-06: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    334.609985
# GS     955.469971
# MS     187.750000
# BAC     57.250000
# C      122.500000
# Name: 2026-01-06 00:00:00, dtype: float64
#
# 2026-01-07: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    326.989990
# GS     941.020020
# MS     184.789993
# BAC     55.639999
# C      121.370003
# Name: 2026-01-07 00:00:00, dtype: float64
#
# 2026-01-08: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    329.790009
# GS     934.830017
# MS     184.679993
# BAC     56.180000
# C      120.599998
# Name: 2026-01-08 00:00:00, dtype: float64
#
# 2026-01-09: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    329.190002
# GS     938.979980
# MS     186.320007
# BAC     55.849998
# C      121.320000
# Name: 2026-01-09 00:00:00, dtype: float64
#
# 2026-01-12: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    324.489990
# GS     949.549988
# MS     186.570007
# BAC     55.189999
# C      117.699997
# Name: 2026-01-12 00:00:00, dtype: float64
#
# 2026-01-13: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    310.899994
# GS     938.150024
# MS     182.759995
# BAC     54.540001
# C      116.300003
# Name: 2026-01-13 00:00:00, dtype: float64
#
# 2026-01-14: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    307.869995
# GS     932.669983
# MS     180.779999
# BAC     52.480000
# C      112.410004
# Name: 2026-01-14 00:00:00, dtype: float64
#
# 2026-01-15: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    309.260010
# GS     975.859985
# MS     191.229996
# BAC     52.590000
# C      117.459999
# Name: 2026-01-15 00:00:00, dtype: float64
#
# 2026-01-16: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    312.470001
# GS     962.000000
# MS     189.089996
# BAC     52.970001
# C      118.040001
# Name: 2026-01-16 00:00:00, dtype: float64
#
# 2026-01-19: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    312.470001
# GS     962.000000
# MS     189.089996
# BAC     52.970001
# C      118.040001
# Name: 2026-01-19 00:00:00, dtype: float64
#
# 2026-01-20: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    302.739990
# GS     943.369995
# MS     182.100006
# BAC     52.099998
# C      112.800003
# Name: 2026-01-20 00:00:00, dtype: float64
#
# 2026-01-21: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    302.040009
# GS     953.010010
# MS     183.320007
# BAC     52.070000
# C      113.860001
# Name: 2026-01-21 00:00:00, dtype: float64
#
# 2026-01-22: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    303.630005
# GS     954.650024
# MS     183.050003
# BAC     52.450001
# C      115.660004
# Name: 2026-01-22 00:00:00, dtype: float64
#
# 2026-01-23: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    297.720001
# GS     918.880005
# MS     179.000000
# BAC     51.720001
# C      113.589996
# Name: 2026-01-23 00:00:00, dtype: float64
#
# 2026-01-26: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    301.040009
# GS     931.859985
# MS     181.880005
# BAC     52.020000
# C      114.820000
# Name: 2026-01-26 00:00:00, dtype: float64
#
# 2026-01-27: executing pending target
# JPM    0.2
# GS     0.2
# MS     0.2
# BAC    0.2
# C      0.2
# dtype: float64
# Current prices executed at:
# JPM    300.170013
# GS     928.679993
# MS     183.044006
# BAC     52.215000
# C      114.839996
# Name: 2026-01-27 00:00:00, dtype: float64

# %% [markdown]
# # RUN

# %%
results = btr.VisualiseBacktestResults(backtester, riskfree=0.0)
results.plot_pnl_curve()

# %% [markdown]
# Function needs to
# Input: tradable assets; data set; position_history;
# Return: cash , serires: stocks+weights
