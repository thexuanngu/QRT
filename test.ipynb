# %% [markdown]
# # 1. Data Retrieval, Visualizations, and Preprocessing (Standardizing, Missing Data, Outliers)

# %% [markdown]
# ## Xuanthe's thoughts:
#
# Let's just grab `yfin` data to pilot our strategies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv('data/data.csv')
df.head()
df = df.iloc[1:,:]
df.head()

df_temp = df.iloc[:250, :]
df.head()
# Out:
#          Date NVDA.O (TRDPRC_1) JPM (TRDPRC_1) GS (TRDPRC_1)  \
# 1  21/11/2025             182.8         298.76        778.99
# 2  20/11/2025            180.64         298.38         773.7
# 3  19/11/2025            186.52         303.27        785.99
# 4  18/11/2025            181.36         299.41         776.3
# 5  17/11/2025             186.6         300.37        775.56
#
#   AAPL.O (TRDPRC_1) MSFT.O (TRDPRC_1) TSLA.O (TRDPRC_1) META.O (TRDPRC_1)  \
# 1            272.88            475.14            400.57            596.86
# 2            266.25            478.43            395.23            589.15
# 3            268.56            487.12            403.99            590.32
# 4            267.44            493.79            401.25            597.69
# 5            267.46            507.49            408.92            602.01
#
#   GOOGL.O (TRDPRC_1) BLK (TRDPRC_1)  ... TSM (TRDPRC_1) XAU= (BID)  \
# 1             302.23         1009.2  ...         277.67    4090.59
# ...

# %%
for stock in df.columns[1:]:
    plt.figure(figsize=(10, 5))
    plt.scatter(df_temp['Date'], df_temp[stock], label=stock)
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title(f'Stock Price of {stock} Over Time')
    plt.legend()
plt.show()

# %% [markdown]
# # 2. Generate an idea for a model, and test the idea for some data (Bonus, calculate the risk / covariances)

# %% [markdown]
# # 3. Generate a portfolio and backtest the portfolio

# %% [markdown]
# # 4. Risk Management (think about making our portfolio more robust to outlier events)
