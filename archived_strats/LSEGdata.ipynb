# %%
import sys
sys.path.append(r"C:\Users\trund\QRT")

from backtest.backtesting import Backtester, FunctionStrategy# To backtest the strategy
from backtest.backtest_results import VisualiseBacktestResults
import eda_package

from typing import Optional, List, Tuple, Dict
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm 
import scipy.stats as stats
import yfinance as yf

# %% [markdown]
# ## Usage Instructions
#
# **For COVID Period Analysis:**
#
# 1. **Before COVID**
#    - `ANALYSIS_START = "2019-01-01"`
#    - `ANALYSIS_END = "2020-03-01"` (right before lockdowns)
#
# 2. **During COVID**:
#    - `ANALYSIS_START = "2020-03-01"`
#    - `ANALYSIS_END = "2021-06-01"`
#
# 3. **Post-COVID**:
#    - `ANALYSIS_START = "2021-06-01"`
#    - `ANALYSIS_END = "2022-12-31"`
#
# **Important:**
# - Always use `dataset_analysis` (not `dataset`) for backtesting to ensure proper date filtering
# - The code automatically fetches 285 extra days before `ANALYSIS_START` to calculate the 200-day MA
# - All moving averages will be valid from the start of your analysis period

# %%
# Updated function with date parameters instead of period
def generate_jd_dataset_with_dates(ticker, start_date, end_date, sma_windows, interval='1d') -> pd.DataFrame:
    """
    Generate dataset with technical indicators using specific date range.
    
    Parameters:
    -----------
    ticker : str
        Stock ticker symbol
    start_date : str
        Start date for data download (should be ~285 days before analysis start for 200-day MA)
    end_date : str
        End date for data download
    sma_windows : list
        List of SMA window periods [short, medium, long]
    interval : str
        Data interval: '1d' for daily (default), '1wk' for weekly, '1mo' for monthly
    """
    
    # 1. Download data using specific dates and interval
    data = yf.download(ticker, start=start_date, end=end_date, interval=interval, auto_adjust=False)
    df = data.copy()

    # Flatten Multi-Index if necessary
    if isinstance(data.columns, pd.MultiIndex):
        # Change the columns to their names 
        df.columns = [f"{column[0]}" for column in df.columns]

    # Adjust names of columns before proceeding
    df.columns = [column.replace(" ", "_") for column in df.columns]

    calculated_with = "Adj_Close"

    # 2. Simple Moving Average (using Adjusted Close for better accuracy)
    for i in range(len(sma_windows)):
        df[f"SMA_{sma_windows[i]}"] = df[calculated_with].rolling(window=sma_windows[i]).mean()

    # 3. Momentum Signal (RSI)
    delta = df[calculated_with].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
    rs = gain / loss
    df[f'Momentum_RSI'] = 100 - (100 / (1 + rs))

    # 4. Log Returns (calculated on Adjusted Close)
    df[f'Log_Returns'] = np.log(df[calculated_with] / df[calculated_with].shift(1))

    # 5. Unusual Volume Logic
    vol_avg = df[f'Volume'].rolling(window=20).mean()
    vol_std = df[f'Volume'].rolling(window=20).std()
    df['Unusual_Volume'] = np.where(df[f'Volume'] > (vol_avg + 1.5 * vol_std), 1, 0)

    # Drop NaNs and reorder for clarity - verified that the only missing dates are from SMA
    df.columns = [f"{ticker}_{column}" for column in df.columns]
    df.dropna(inplace=True)

    # Technically this line is not needed 
    cols = [calculated_with, f'Volume', f"SMA_{sma_windows[0]}", f"SMA_{sma_windows[1]}", f"SMA_{sma_windows[2]}", f'Momentum_RSI', f'Log_Returns', 'Unusual_Volume']
    cols = [f"{ticker}_{column}" for column in cols]

    return df[cols].rename(columns={f"{ticker}_Adj_Close": ticker})

# %%
# Date configuration for COVID period analysis
from datetime import datetime, timedelta

# Define your actual analysis period (e.g., before COVID - March 2020)
ANALYSIS_START = "2023-01-01"  # Start of 2025 tumble
ANALYSIS_END = "2025-03-31"    # Q1 aftermath

# Calculate data fetch start date (200 trading days ≈ 285 calendar days to be safe)
analysis_start_dt = datetime.strptime(ANALYSIS_START, "%Y-%m-%d")
data_fetch_start = (analysis_start_dt - timedelta(days=285)).strftime("%Y-%m-%d")

print(f"Fetching data from: {data_fetch_start}")
print(f"Analysis period: {ANALYSIS_START} to {ANALYSIS_END}")
print(f"Extra days for 200-day MA warm-up: ~285 days")
# Out:
# Fetching data from: 2022-03-22
# Analysis period: 2023-01-01 to 2025-03-31
# Extra days for 200-day MA warm-up: ~285 days

# %%
# Generate dataset with date-based approach
tickers = ["NVDA", "TSLA", "AAPL", "AMZN", "MSFT", "META", "GOOGL"]
sma_windows = [2, 1, 28] 
datasets = []

print(f"Downloading data from {data_fetch_start} to {ANALYSIS_END}...")
print(f"This includes ~285 extra days for 200-day MA calculation\n")

for ticker in tickers:
    print(f"Downloading {ticker}...")
    datasets.append(generate_jd_dataset_with_dates(
        ticker=ticker, 
        start_date=data_fetch_start,  # Start earlier for MA warm-up
        end_date=ANALYSIS_END,        # End at your analysis cutoff
        sma_windows=sma_windows,
        interval="1wk"
    ))

dataset = pd.concat(datasets, axis=1)

# Filter to actual analysis period (remove warm-up period)
dataset_analysis = dataset.loc[ANALYSIS_START:ANALYSIS_END]

print(f"\n✓ Full dataset shape: {dataset.shape}")
print(f"✓ Analysis dataset shape: {dataset_analysis.shape}")
print(f"✓ Full date range: {dataset.index[0].strftime('%Y-%m-%d')} to {dataset.index[-1].strftime('%Y-%m-%d')}")
print(f"✓ Analysis date range: {dataset_analysis.index[0].strftime('%Y-%m-%d')} to {dataset_analysis.index[-1].strftime('%Y-%m-%d')}")

dataset_analysis
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading data from 2022-03-22 to 2025-03-31...
# This includes ~285 extra days for 200-day MA calculation
#
# Downloading NVDA...
# Downloading TSLA...
# Downloading AAPL...
# Downloading AMZN...
# Downloading MSFT...
# Downloading META...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading GOOGL...
#
# ✓ Full dataset shape: (131, 56)
# ✓ Analysis dataset shape: (117, 56)
# ✓ Full date range: 2022-09-26 to 2025-03-24
# ✓ Analysis date range: 2023-01-02 to 2025-03-24
#                   NVDA  NVDA_Volume  NVDA_SMA_2  NVDA_SMA_1  NVDA_SMA_28  \
# Date
# 2023-01-02   14.844139   1626813000   14.721763   14.844139    15.200788
# 2023-01-09   16.882105   2240313000   15.863122   16.882105    15.285846
# 2023-01-16   17.821159   1968625000   17.351632   17.821159    15.357552
# 2023-01-23   20.344635   2632581000   19.082897   20.344635    15.522091
# 2023-01-30   21.078899   2640747000   20.711767   21.078899    15.657333
# ...                ...          ...         ...         ...          ...
# 2025-02-24  124.885841   1677630500  129.639538  124.885841   132.448607
# 2025-03-03  112.659187   1756820000  118.772514  112.659187   131.853770
# 2025-03-10  121.636726   1621837200  117.147957  121.636726   131.936548
# 2025-03-17  117.678635   1343942800  119.657681  117.678635   132.468427
# 2025-03-24  109.650101   1156137600  113.664368  109.650101   132.132751
#
#             NVDA_Momentum_RSI  NVDA_Log_Returns  NVDA_Unusual_Volume  \
# Date
# 2023-01-02          62.204469          0.016626                    0
# 2023-01-09          68.373649          0.128649                    0
# 2023-01-16          75.010094          0.054132                    0
# 2023-01-23          77.226919          0.132431                    0
# 2023-01-30          76.188854          0.035455                    0
# ...                       ...               ...                  ...
# 2025-02-24          41.210345         -0.073370                    0
# 2025-03-03          37.873506         -0.103033                    0
# 2025-03-10          40.575557          0.076672                    0
# 2025-03-17          42.192545         -0.033081                    0
# 2025-03-24          38.978001         -0.070663                    0
#
#                   TSLA  TSLA_Volume  ...  META_Log_Returns  \
# Date                                 ...
# 2023-01-02  113.059998    790689200  ...          0.077367
# 2023-01-09  122.400002    891852300  ...          0.052146
# 2023-01-16  133.419998    691307300  ...          0.017297
# 2023-01-23  177.899994   1095958300  ...          0.085037
# 2023-01-30  189.979996   1091608900  ...          0.206423
# ...                ...          ...  ...               ...
# 2025-02-24  292.980011    527844600  ...         -0.022712
# 2025-03-03  262.670013    537122100  ...         -0.065780
# 2025-03-10  249.979996    721244800  ...         -0.029290
# 2025-03-17  248.710007    567129000  ...         -0.017967
# 2025-03-24  263.549988    759452700  ...         -0.033268
#
#             META_Unusual_Volume       GOOGL  GOOGL_Volume  GOOGL_SMA_2  \
# Date
# 2023-01-02                    0   86.685028     131561900    87.126694
# 2023-01-09                    0   91.429184     142921000    89.057106
# 2023-01-16                    0   97.284943     161910600    94.357063
# 2023-01-23                    0   98.624817     179407400    97.954880
# 2023-01-30                    0  103.994247     227821100   101.309532
# ...                         ...         ...           ...          ...
# 2025-02-24                    0  169.615707     195320500   174.287407
# 2025-03-03                    0  173.181732     172801200   171.398720
# 2025-03-10                    0  164.844391     175315900   169.013062
# 2025-03-17                    1  163.538376     172299000   164.191383
# 2025-03-24                    0  153.904968     157132700   158.721672
#
#             GOOGL_SMA_1  GOOGL_SMA_28  GOOGL_Momentum_RSI  GOOGL_Log_Returns  \
# Date
# 2023-01-02    86.685028    101.566466           41.889514          -0.010139
# 2023-01-09    91.429184    100.977434           43.808998           0.053284
# 2023-01-16    97.284943    100.221237           51.286129           0.062079
# 2023-01-23    98.624817     99.781435           48.356360           0.013679
# 2023-01-30   103.994247     99.670842           57.845137           0.053013
# ...                 ...           ...                 ...                ...
# 2025-02-24   169.615707    175.346136           53.799224          -0.053622
# 2025-03-03   173.181732    175.653817           53.424018           0.020806
# 2025-03-10   164.844391    175.743227           44.153483          -0.049340
# 2025-03-17   163.538376    176.228163           29.936493          -0.007954
# 2025-03-24   153.904968    176.136963           24.093579          -0.060712
#
#             GOOGL_Unusual_Volume
# Date
# 2023-01-02                     0
# 2023-01-09                     0
# 2023-01-16                     0
# 2023-01-23                     0
# 2023-01-30                     0
# ...                          ...
# 2025-02-24                     0
# 2025-03-03                     0
# 2025-03-10                     0
# 2025-03-17                     0
# 2025-03-24                     0
#
# [117 rows x 56 columns]

# %% [markdown]
# ## Strategy 1 - Moving Average Crossover

# %%
# Overall, the strategy looks decent, should try implementing it. Buy when 10_SMA > 200_SMA, sell when 200_SMA > 10_SMA. In weekly terms

def sma_crossover_strategy_base(tradable_assets, history, position_history, short_window=10, long_window=200):

    # Initialise the labels and weights object
    n = len(tradable_assets)
    labels_and_weights = pd.Series(data=np.zeros(n, dtype=float), index=tradable_assets)
    cash = 0.1  # liquidity reserves
    
    # Create a signal for each tradable asset
    for asset in tradable_assets:
        short_sma = history.iloc[-1].get(f"{asset}_SMA_{short_window}", np.nan)
        long_sma = history.iloc[-1].get(f"{asset}_SMA_{long_window}", np.nan)

        # If we don't have SMA values, skip (signal -> 0)
        if pd.isna(short_sma) or pd.isna(long_sma):
            labels_and_weights[asset] = 0.0
            continue

        if short_sma > long_sma:
            labels_and_weights[asset] = float(short_sma - long_sma)
        else:
            labels_and_weights[asset] = 0.0

    # If there are any positive signals, scale them to available NAV (1 - cash)
    total_signal = labels_and_weights.sum()
    if total_signal > 0:
        labels_and_weights = (labels_and_weights / total_signal) * (1 - cash)
    else:
        # Signal says hold nothing -> set all weights to zero and allocate to cash
        labels_and_weights[:] = 0.0
        cash = 1.0

    # Prepare previous position vector (align indices and fill missing with 0)
    prev_pos = position_history.iloc[-1] 

    # Decide whether to rebalance:
    # - rebalance when total absolute change > threshold
    # - OR when any existing position should be fully exited (signal -> 0)
    abs_diff = np.abs(prev_pos - labels_and_weights).sum()
    exit_needed = ((prev_pos > 1e-12) & (labels_and_weights == 0.0)).any()
    rebalance_threshold = 0.1

    if abs_diff < rebalance_threshold and not exit_needed:
        # No meaningful change and no required exits -> skip rebalancing
        return None, None

    return cash, labels_and_weights

# %% [markdown]
# ### Moving Average Crossover - Covid Backtest

# %%
# Specialised strategy + tickers
tradable_assets = tickers
def sma_crossover_strategy(tradable_assets, history, position_history):
    return sma_crossover_strategy_base(tradable_assets, history, position_history, short_window=sma_windows[0], long_window=sma_windows[2])

backtest = Backtester(tradable_assets=tradable_assets, 
                       strategy_fn = FunctionStrategy(sma_crossover_strategy, tradable_assets = tradable_assets), 
                       strategy_name = "sma_crossover_strategy", 
                       allow_short=True,
                       data = dataset_analysis, 
                       slippage=0.00, 
                       commission=0.05)



backtest.run(verbose=True)
#sma_crossover_strategy(tradable_assets, nvda_adj, position_history=0)

print("Total Number of Trades Made (including Portfolio Rebalances), ", len(backtest.trades))
# Out:
# 2023-01-16: executing pending target
# NVDA     0.9
# TSLA     0.0
# AAPL     0.0
# AMZN     0.0
# MSFT     0.0
# META     0.0
# GOOGL    0.0
# dtype: float64
# Current prices executed at:
# NVDA      17.821159
# TSLA     133.419998
# AAPL     135.694000
# AMZN      97.250000
# MSFT     234.610703
# META     138.403183
# GOOGL     97.284943
# Name: 2023-01-16 00:00:00, dtype: float64
#
# 2023-01-23: executing pending target
# NVDA     0.612661
# TSLA     0.000000
# AAPL     0.000000
# AMZN     0.000000
# MSFT     0.000000
# META     0.287339
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA      20.344635
# TSLA     177.899994
# AAPL     143.626801
# AMZN     102.239998
# MSFT     242.365295
# META     150.687424
# GOOGL     98.624817
# Name: 2023-01-23 00:00:00, dtype: float64
#
# 2023-01-30: executing pending target
# NVDA     0.260875
# TSLA     0.000000
# AAPL     0.000000
# AMZN     0.000000
# MSFT     0.000000
# META     0.639125
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA      21.078899
# TSLA     189.979996
# AAPL     152.061539
# AMZN     103.389999
# MSFT     252.317383
# META     185.236069
# GOOGL    103.994247
# Name: 2023-01-30 00:00:00, dtype: float64
#
# 2023-02-06: executing pending target
# NVDA     0.101237
# TSLA     0.000000
# AAPL     0.045605
# AMZN     0.000000
# MSFT     0.088849
# META     0.631487
# GOOGL    0.032822
# dtype: float64
# Current prices executed at:
# NVDA      21.243734
# TSLA     196.889999
# AAPL     148.626602
# AMZN      97.610001
# MSFT     256.956482
# META     172.941956
# GOOGL     93.860817
# Name: 2023-02-06 00:00:00, dtype: float64
#
# 2023-02-13: executing pending target
# NVDA     0.074667
# TSLA     0.000000
# AAPL     0.071492
# AMZN     0.000000
# MSFT     0.170277
# META     0.583181
# GOOGL    0.000383
# dtype: float64
# Current prices executed at:
# NVDA      21.366611
# TSLA     208.309998
# AAPL     150.371552
# AMZN      97.199997
# MSFT     252.034119
# META     171.680740
# GOOGL     93.642456
# Name: 2023-02-13 00:00:00, dtype: float64
#
# 2023-02-20: executing pending target
# NVDA     0.084135
# TSLA     0.000000
# AAPL     0.073206
# AMZN     0.000000
# MSFT     0.200276
# META     0.542383
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA      23.262712
# TSLA     196.880005
# AAPL     144.614944
# AMZN      93.500000
# MSFT     244.010193
# META     169.208023
# GOOGL     88.461609
# Name: 2023-02-20 00:00:00, dtype: float64
#
# 2023-02-27: executing pending target
# NVDA     0.110128
# TSLA     0.000000
# AAPL     0.063165
# AMZN     0.000000
# MSFT     0.138506
# META     0.588201
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA      23.866106
# TSLA     197.789993
# AAPL     148.873291
# AMZN      94.900002
# MSFT     249.953293
# META     183.964935
# GOOGL     92.947716
# Name: 2023-02-27 00:00:00, dtype: float64
#
# 2023-03-06: executing pending target
# NVDA     0.113870
# TSLA     0.000000
# AAPL     0.055370
# AMZN     0.000000
# MSFT     0.122464
# META     0.608296
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA      22.942038
# TSLA     173.440002
# AAPL     146.379395
# AMZN      90.730003
# MSFT     243.393356
# META     178.264740
# GOOGL     89.950356
# Name: 2023-03-06 00:00:00, dtype: float64
#
# 2023-03-20: executing pending target
# NVDA     0.082739
# TSLA     0.000000
# AAPL     0.077278
# AMZN     0.000000
# MSFT     0.213710
# META     0.523684
# GOOGL    0.002590
# dtype: float64
# Current prices executed at:
# NVDA      26.756762
# TSLA     190.410004
# AAPL     157.961594
# AMZN      98.129997
# MSFT     274.704895
# META     204.580948
# GOOGL    104.649300
# Name: 2023-03-20 00:00:00, dtype: float64
#
# 2023-03-27: executing pending target
# NVDA     0.065392
# TSLA     0.000000
# AAPL     0.092760
# AMZN     0.000000
# MSFT     0.251795
# META     0.432880
# GOOGL    0.057173
# dtype: float64
# Current prices executed at:
# NVDA      27.753933
# TSLA     207.460007
# AAPL     162.545181
# AMZN     103.290001
# MSFT     282.273224
# META     210.469788
# GOOGL    102.952126
# Name: 2023-03-27 00:00:00, dtype: float64
#
# 2023-04-03: executing pending target
# NVDA     0.055942
# TSLA     0.070989
# AAPL     0.101086
# AMZN     0.014445
# MSFT     0.220356
# META     0.384858
# GOOGL    0.052324
# dtype: float64
# Current prices executed at:
# NVDA      27.014551
# TSLA     185.059998
# AAPL     162.308655
# AMZN     102.059998
# MSFT     285.504272
# META     214.600983
# GOOGL    107.606956
# Name: 2023-04-03 00:00:00, dtype: float64
#
# 2023-04-10: executing pending target
# NVDA     0.049938
# TSLA     0.069159
# AAPL     0.103332
# AMZN     0.026681
# MSFT     0.224526
# META     0.371330
# GOOGL    0.055033
# dtype: float64
# Current prices executed at:
# NVDA      26.735781
# TSLA     185.000000
# AAPL     162.850754
# AMZN     102.510002
# MSFT     280.158417
# META     219.953537
# GOOGL    108.053581
# Name: 2023-04-10 00:00:00, dtype: float64
#
# 2023-04-17: executing pending target
# NVDA     0.046939
# TSLA     0.024141
# AAPL     0.104901
# AMZN     0.028233
# MSFT     0.220898
# META     0.404200
# GOOGL    0.070689
# dtype: float64
# Current prices executed at:
# NVDA      27.096481
# TSLA     165.080002
# AAPL     162.663467
# AMZN     106.959999
# MSFT     279.786346
# META     211.413208
# GOOGL    104.619530
# Name: 2023-04-17 00:00:00, dtype: float64
#
# 2023-04-24: executing pending target
# NVDA     0.048261
# TSLA     0.000000
# AAPL     0.110392
# AMZN     0.048535
# MSFT     0.211814
# META     0.414682
# GOOGL    0.066315
# dtype: float64
# Current prices executed at:
# NVDA      27.725958
# TSLA     164.309998
# AAPL     167.256927
# AMZN     105.449997
# MSFT     300.836884
# META     238.652924
# GOOGL    106.535042
# Name: 2023-04-24 00:00:00, dtype: float64
#
# 2023-05-01: executing pending target
# NVDA     0.043232
# TSLA     0.000000
# AAPL     0.106520
# AMZN     0.052954
# MSFT     0.236393
# META     0.407424
# GOOGL    0.053477
# dtype: float64
# Current prices executed at:
# NVDA      28.656183
# TSLA     170.059998
# AAPL     171.091400
# AMZN     105.660004
# MSFT     304.156036
# META     231.165222
# GOOGL    104.778320
# Name: 2023-05-01 00:00:00, dtype: float64
#
# 2023-05-15: executing pending target
# NVDA     0.038927
# TSLA     0.000000
# AAPL     0.117820
# AMZN     0.058396
# MSFT     0.255716
# META     0.358531
# GOOGL    0.070610
# dtype: float64
# Current prices executed at:
# NVDA      31.238041
# TSLA     180.139999
# AAPL     172.897476
# AMZN     116.250000
# MSFT     311.685242
# META     243.936020
# GOOGL    121.839417
# Name: 2023-05-15 00:00:00, dtype: float64
#
# 2023-05-22: executing pending target
# NVDA     0.039184
# TSLA     0.006704
# AAPL     0.106531
# AMZN     0.075227
# MSFT     0.237242
# META     0.334706
# GOOGL    0.100406
# dtype: float64
# Current prices executed at:
# NVDA      38.913658
# TSLA     193.169998
# AAPL     173.164032
# AMZN     120.110001
# MSFT     326.643616
# META     260.222290
# GOOGL    123.675545
# Name: 2023-05-22 00:00:00, dtype: float64
#
# 2023-05-29: executing pending target
# NVDA     0.049700
# TSLA     0.055823
# AAPL     0.089083
# AMZN     0.078008
# MSFT     0.228714
# META     0.306966
# GOOGL    0.091705
# dtype: float64
# Current prices executed at:
# NVDA      39.294342
# TSLA     213.970001
# AAPL     178.612732
# AMZN     124.250000
# MSFT     329.106506
# META     270.718964
# GOOGL    123.735085
# Name: 2023-05-29 00:00:00, dtype: float64
#
# 2023-06-05: executing pending target
# NVDA     0.053634
# TSLA     0.101723
# AAPL     0.082834
# AMZN     0.077153
# MSFT     0.215181
# META     0.290580
# GOOGL    0.078895
# dtype: float64
# Current prices executed at:
# NVDA      38.737804
# TSLA     244.399994
# AAPL     178.622574
# AMZN     123.430000
# MSFT     320.658173
# META     263.112091
# GOOGL    121.313400
# Name: 2023-06-05 00:00:00, dtype: float64
#
# 2023-06-12: executing pending target
# NVDA     0.048247
# TSLA     0.173298
# AAPL     0.084066
# AMZN     0.075494
# MSFT     0.186277
# META     0.264086
# GOOGL    0.068532
# dtype: float64
# Current prices executed at:
# NVDA      42.660965
# TSLA     260.540009
# AAPL     182.531448
# AMZN     125.489998
# MSFT     335.906494
# META     279.050690
# GOOGL    122.603645
# Name: 2023-06-12 00:00:00, dtype: float64
#
# 2023-06-19: executing pending target
# NVDA     0.047410
# TSLA     0.225719
# AAPL     0.080505
# AMZN     0.069035
# MSFT     0.175004
# META     0.242491
# GOOGL    0.059836
# dtype: float64
# Current prices executed at:
# NVDA      42.178314
# TSLA     256.600006
# AAPL     184.268661
# AMZN     129.330002
# MSFT     328.733643
# META     286.727112
# GOOGL    121.422554
# Name: 2023-06-19 00:00:00, dtype: float64
#
# 2023-06-26: executing pending target
# NVDA     0.047892
# TSLA     0.226329
# AAPL     0.080872
# AMZN     0.070665
# MSFT     0.170439
# META     0.249281
# GOOGL    0.054521
# dtype: float64
# Current prices executed at:
# NVDA      42.271248
# TSLA     261.769989
# AAPL     191.464523
# AMZN     130.360001
# MSFT     334.150055
# META     284.989258
# GOOGL    118.802353
# Name: 2023-06-26 00:00:00, dtype: float64
#
# 2023-08-07: executing pending target
# NVDA     0.051783
# TSLA     0.187973
# AAPL     0.070330
# AMZN     0.089388
# MSFT     0.119667
# META     0.308734
# GOOGL    0.072126
# dtype: float64
# Current prices executed at:
# NVDA      40.825294
# TSLA     242.649994
# AAPL     175.493530
# AMZN     138.410004
# MSFT     314.986572
# META     299.547577
# GOOGL    128.588425
# Name: 2023-08-07 00:00:00, dtype: float64
#
# 2023-08-14: executing pending target
# NVDA     0.049773
# TSLA     0.176355
# AAPL     0.042243
# AMZN     0.126885
# MSFT     0.101893
# META     0.320702
# GOOGL    0.082148
# dtype: float64
# Current prices executed at:
# NVDA      43.267517
# TSLA     215.490005
# AAPL     172.468735
# AMZN     133.220001
# MSFT     310.541565
# META     281.285126
# GOOGL    126.504166
# Name: 2023-08-14 00:00:00, dtype: float64
#
# 2023-08-21: executing pending target
# NVDA     0.061550
# TSLA     0.109652
# AAPL     0.029916
# AMZN     0.153539
# MSFT     0.092483
# META     0.341629
# GOOGL    0.111230
# dtype: float64
# Current prices executed at:
# NVDA      45.984547
# TSLA     238.589996
# AAPL     176.541016
# AMZN     133.259995
# MSFT     317.590546
# META     283.519562
# GOOGL    128.906021
# Name: 2023-08-21 00:00:00, dtype: float64
#
# 2023-08-28: executing pending target
# NVDA     0.088323
# TSLA     0.100274
# AAPL     0.031606
# AMZN     0.149828
# MSFT     0.102939
# META     0.303697
# GOOGL    0.123332
# dtype: float64
# Current prices executed at:
# NVDA      48.473732
# TSLA     245.009995
# AAPL     187.265350
# AMZN     138.119995
# MSFT     323.175751
# META     294.324066
# GOOGL    134.642670
# Name: 2023-08-28 00:00:00, dtype: float64
#
# 2023-09-04: executing pending target
# NVDA     0.079073
# TSLA     0.167745
# AAPL     0.065258
# AMZN     0.122132
# MSFT     0.104741
# META     0.248469
# GOOGL    0.112581
# dtype: float64
# Current prices executed at:
# NVDA      45.538864
# TSLA     248.500000
# AAPL     176.115997
# AMZN     138.229996
# MSFT     328.692169
# META     295.823578
# GOOGL    135.357269
# Name: 2023-09-04 00:00:00, dtype: float64
#
# 2023-09-11: executing pending target
# NVDA     0.068463
# TSLA     0.178848
# AAPL     0.053333
# AMZN     0.121431
# MSFT     0.115395
# META     0.245924
# GOOGL    0.116606
# dtype: float64
# Current prices executed at:
# NVDA      43.871696
# TSLA     274.390015
# AAPL     172.982727
# AMZN     140.389999
# MSFT     324.709778
# META     298.226776
# GOOGL    136.369614
# Name: 2023-09-11 00:00:00, dtype: float64
#
# 2023-09-18: executing pending target
# NVDA     0.050775
# TSLA     0.263024
# AAPL     0.002385
# AMZN     0.122002
# MSFT     0.106486
# META     0.239600
# GOOGL    0.115727
# dtype: float64
# Current prices executed at:
# NVDA      41.583179
# TSLA     244.880005
# AAPL     172.765228
# AMZN     129.119995
# MSFT     311.720123
# META     297.005310
# GOOGL    129.273224
# Name: 2023-09-18 00:00:00, dtype: float64
#
# 2023-09-25: executing pending target
# NVDA     0.043714
# TSLA     0.306770
# AAPL     0.000000
# AMZN     0.108703
# MSFT     0.045359
# META     0.282231
# GOOGL    0.113223
# dtype: float64
# Current prices executed at:
# NVDA      43.470951
# TSLA     250.220001
# AAPL     169.226715
# AMZN     127.120003
# MSFT     310.481201
# META     298.127533
# GOOGL    129.878647
# Name: 2023-09-25 00:00:00, dtype: float64
#
# 2023-10-02: executing pending target
# NVDA     0.056012
# TSLA     0.277879
# AAPL     0.000000
# AMZN     0.065847
# MSFT     0.000000
# META     0.383156
# GOOGL    0.117107
# dtype: float64
# Current prices executed at:
# NVDA      45.732502
# TSLA     260.529999
# AAPL     175.433990
# AMZN     127.959999
# MSFT     321.799133
# META     313.241913
# GOOGL    136.548279
# Name: 2023-10-02 00:00:00, dtype: float64
#
# 2023-10-09: executing pending target
# NVDA     0.063304
# TSLA     0.295994
# AAPL     0.000000
# AMZN     0.037528
# MSFT     0.002202
# META     0.373359
# GOOGL    0.127613
# dtype: float64
# Current prices executed at:
# NVDA      45.431694
# TSLA     251.119995
# AAPL     176.778214
# AMZN     129.789993
# MSFT     322.261292
# META     312.507019
# GOOGL    136.329926
# Name: 2023-10-09 00:00:00, dtype: float64
#
# 2023-10-16: executing pending target
# NVDA     0.059989
# TSLA     0.253040
# AAPL     0.000000
# AMZN     0.037381
# MSFT     0.046647
# META     0.368695
# GOOGL    0.134248
# dtype: float64
# Current prices executed at:
# NVDA      41.360317
# TSLA     211.990005
# AAPL     170.877380
# AMZN     125.169998
# MSFT     321.218994
# META     306.508942
# GOOGL    134.583145
# Name: 2023-10-16 00:00:00, dtype: float64
#
# 2023-10-23: executing pending target
# NVDA     0.059779
# TSLA     0.000662
# AAPL     0.000000
# AMZN     0.027466
# MSFT     0.056157
# META     0.547835
# GOOGL    0.208101
# dtype: float64
# Current prices executed at:
# NVDA      40.473892
# TSLA     207.300003
# AAPL     166.271347
# AMZN     127.739998
# MSFT     324.306580
# META     294.671600
# GOOGL    121.253838
# Name: 2023-10-23 00:00:00, dtype: float64
#
# 2023-10-30: executing pending target
# NVDA     0.011656
# TSLA     0.000000
# AAPL     0.000000
# AMZN     0.000000
# MSFT     0.091775
# META     0.671825
# GOOGL    0.124745
# dtype: float64
# Current prices executed at:
# NVDA      44.975983
# TSLA     219.960007
# AAPL     174.603683
# AMZN     138.600006
# MSFT     346.912964
# META     312.417694
# GOOGL    128.131866
# Name: 2023-10-30 00:00:00, dtype: float64
#
# 2023-11-06: executing pending target
# NVDA     0.035723
# TSLA     0.000000
# AAPL     0.000000
# AMZN     0.123848
# MSFT     0.311045
# META     0.429383
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA      48.303844
# TSLA     214.649994
# AAPL     184.240784
# AMZN     143.559998
# MSFT     363.501434
# META     326.489380
# GOOGL    131.595718
# Name: 2023-11-06 00:00:00, dtype: float64
#
# 2023-11-13: executing pending target
# NVDA     0.051141
# TSLA     0.000000
# AAPL     0.012180
# AMZN     0.128303
# MSFT     0.332213
# META     0.336086
# GOOGL    0.040076
# dtype: float64
# Current prices executed at:
# NVDA      49.266220
# TSLA     234.300003
# AAPL     187.739655
# AMZN     145.179993
# MSFT     363.678467
# META     332.715912
# GOOGL    134.295303
# Name: 2023-11-13 00:00:00, dtype: float64
#
# 2023-11-20: executing pending target
# NVDA     0.051492
# TSLA     0.000000
# AAPL     0.060005
# AMZN     0.115156
# MSFT     0.309967
# META     0.315210
# GOOGL    0.048170
# dtype: float64
# Current prices executed at:
# NVDA      47.745197
# TSLA     235.449997
# AAPL     188.016785
# AMZN     146.740005
# MSFT     371.885254
# META     335.883789
# GOOGL    135.664948
# Name: 2023-11-20 00:00:00, dtype: float64
#
# 2023-11-27: executing pending target
# NVDA     0.041447
# TSLA     0.000000
# AAPL     0.067633
# AMZN     0.112684
# MSFT     0.310952
# META     0.310130
# GOOGL    0.057155
# dtype: float64
# Current prices executed at:
# NVDA      46.734856
# TSLA     238.830002
# AAPL     189.273758
# AMZN     147.029999
# MSFT     369.008148
# META     322.566742
# GOOGL    130.871170
# Name: 2023-11-27 00:00:00, dtype: float64
#
# 2023-12-04: executing pending target
# NVDA     0.029656
# TSLA     0.000000
# AAPL     0.076806
# AMZN     0.123658
# MSFT     0.351142
# META     0.273568
# GOOGL    0.045169
# dtype: float64
# Current prices executed at:
# NVDA      47.475376
# TSLA     243.839996
# AAPL     193.697784
# AMZN     147.419998
# MSFT     368.732239
# META     330.441772
# GOOGL    133.977722
# Name: 2023-12-04 00:00:00, dtype: float64
#
# 2023-12-11: executing pending target
# NVDA     0.028070
# TSLA     0.000000
# AAPL     0.104716
# AMZN     0.128892
# MSFT     0.353432
# META     0.247463
# GOOGL    0.037427
# dtype: float64
# Current prices executed at:
# NVDA      48.862778
# TSLA     253.500000
# AAPL     195.538651
# AMZN     149.970001
# MSFT     365.283661
# META     332.596741
# GOOGL    131.605652
# Name: 2023-12-11 00:00:00, dtype: float64
#
# 2023-12-18: executing pending target
# NVDA     0.032980
# TSLA     0.023795
# AAPL     0.121498
# AMZN     0.125897
# MSFT     0.302111
# META     0.257846
# GOOGL    0.035874
# dtype: float64
# Current prices executed at:
# NVDA      48.802807
# TSLA     252.539993
# AAPL     191.609482
# AMZN     153.419998
# MSFT     369.077087
# META     350.938599
# GOOGL    140.428970
# Name: 2023-12-18 00:00:00, dtype: float64
#
# 2023-12-25: executing pending target
# NVDA     0.031611
# TSLA     0.054137
# AAPL     0.095004
# AMZN     0.126932
# MSFT     0.254125
# META     0.285759
# GOOGL    0.052432
# dtype: float64
# Current prices executed at:
# NVDA      49.494423
# TSLA     248.479996
# AAPL     190.550461
# AMZN     151.940002
# MSFT     370.515686
# META     351.504639
# GOOGL    138.642471
# Name: 2023-12-25 00:00:00, dtype: float64
#
# 2024-01-01: executing pending target
# NVDA     0.030419
# TSLA     0.035120
# AAPL     0.068326
# AMZN     0.120237
# MSFT     0.250736
# META     0.322917
# GOOGL    0.072246
# dtype: float64
# Current prices executed at:
# NVDA      49.069660
# TSLA     237.490005
# AAPL     179.317154
# AMZN     145.240005
# MSFT     362.347443
# META     349.508575
# GOOGL    134.712143
# Name: 2024-01-01 00:00:00, dtype: float64
#
# 2024-01-08: executing pending target
# NVDA     0.038081
# TSLA     0.000000
# AAPL     0.028748
# AMZN     0.108669
# MSFT     0.277760
# META     0.386753
# GOOGL    0.059989
# dtype: float64
# Current prices executed at:
# NVDA      54.679543
# TSLA     218.889999
# AAPL     184.008423
# AMZN     154.619995
# MSFT     382.763062
# META     371.892181
# GOOGL    141.580261
# Name: 2024-01-08 00:00:00, dtype: float64
#
# 2024-01-15: executing pending target
# NVDA     0.052552
# TSLA     0.000000
# AAPL     0.000000
# AMZN     0.100248
# MSFT     0.284143
# META     0.404256
# GOOGL    0.058801
# dtype: float64
# Current prices executed at:
# NVDA      59.457878
# TSLA     212.190002
# AAPL     189.590439
# AMZN     155.339996
# MSFT     392.813232
# META     380.790039
# GOOGL    145.282288
# Name: 2024-01-15 00:00:00, dtype: float64
#
# 2024-01-29: executing pending target
# NVDA     0.070155
# TSLA     0.000000
# AAPL     0.043213
# AMZN     0.090145
# MSFT     0.270914
# META     0.346695
# GOOGL    0.078877
# dtype: float64
# Current prices executed at:
# NVDA      66.123154
# TSLA     187.910004
# AAPL     183.939163
# AMZN     171.809998
# MSFT     405.178833
# META     471.695007
# GOOGL    141.312271
# Name: 2024-01-29 00:00:00, dtype: float64
#
# 2024-02-12: executing pending target
# NVDA     0.070584
# TSLA     0.000000
# AAPL     0.013680
# AMZN     0.103361
# MSFT     0.207506
# META     0.470669
# GOOGL    0.034199
# dtype: float64
# Current prices executed at:
# NVDA      72.572571
# TSLA     199.949997
# AAPL     180.665771
# AMZN     169.509995
# MSFT     398.124054
# META     470.036652
# GOOGL    139.466232
# Name: 2024-02-12 00:00:00, dtype: float64
#
# 2024-02-19: executing pending target
# NVDA     0.083405
# TSLA     0.000000
# AAPL     0.008395
# AMZN     0.101903
# MSFT     0.197919
# META     0.476983
# GOOGL    0.031396
# dtype: float64
# Current prices executed at:
# NVDA      78.773125
# TSLA     191.970001
# AAPL     180.873901
# AMZN     174.990005
# MSFT     405.059418
# META     480.672333
# GOOGL    142.880447
# Name: 2024-02-19 00:00:00, dtype: float64
#
# 2024-02-26: executing pending target
# NVDA     0.094926
# TSLA     0.000000
# AAPL     0.000000
# AMZN     0.102611
# MSFT     0.176663
# META     0.504582
# GOOGL    0.021217
# dtype: float64
# Current prices executed at:
# NVDA      82.233185
# TSLA     202.639999
# AAPL     178.039688
# AMZN     178.220001
# MSFT     410.153015
# META     499.344849
# GOOGL    136.111588
# Name: 2024-02-26 00:00:00, dtype: float64
#
# 2024-03-04: executing pending target
# NVDA     0.102286
# TSLA     0.000000
# AAPL     0.000000
# AMZN     0.107028
# MSFT     0.175966
# META     0.502040
# GOOGL    0.012680
# dtype: float64
# Current prices executed at:
# NVDA      87.479256
# TSLA     175.339996
# AAPL     169.190231
# AMZN     175.350006
# MSFT     400.992462
# META     502.973419
# GOOGL    134.394547
# Name: 2024-03-04 00:00:00, dtype: float64
#
# 2024-03-11: executing pending target
# NVDA     0.114450
# TSLA     0.000000
# AAPL     0.000000
# AMZN     0.103723
# MSFT     0.160021
# META     0.521806
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA      87.792213
# TSLA     163.570007
# AAPL     171.063156
# AMZN     174.419998
# MSFT     411.061188
# META     481.251953
# GOOGL    140.121277
# Name: 2024-03-11 00:00:00, dtype: float64
#
# 2024-03-25: executing pending target
# NVDA     0.130076
# TSLA     0.000000
# AAPL     0.000000
# AMZN     0.096316
# MSFT     0.185077
# META     0.458009
# GOOGL    0.030522
# dtype: float64
# Current prices executed at:
# NVDA      90.309929
# TSLA     175.789993
# AAPL     169.933456
# AMZN     180.380005
# MSFT     415.305847
# META     482.723236
# GOOGL    149.798157
# Name: 2024-03-25 00:00:00, dtype: float64
#
# 2024-04-01: executing pending target
# NVDA     0.129345
# TSLA     0.000000
# AAPL     0.000000
# AMZN     0.102908
# MSFT     0.181935
# META     0.438273
# GOOGL    0.047539
# dtype: float64
# Current prices executed at:
# NVDA      87.963127
# TSLA     164.899994
# AAPL     168.050598
# AMZN     185.070007
# MSFT     420.044128
# META     524.237549
# GOOGL    151.356384
# Name: 2024-04-01 00:00:00, dtype: float64
#
# 2024-04-15: executing pending target
# NVDA     0.102920
# TSLA     0.000000
# AAPL     0.000000
# AMZN     0.112788
# MSFT     0.152094
# META     0.473657
# GOOGL    0.058541
# dtype: float64
# Current prices executed at:
# NVDA      76.161140
# TSLA     147.050003
# AAPL     163.511887
# AMZN     174.630005
# MSFT     393.983826
# META     478.239777
# GOOGL    152.934464
# Name: 2024-04-15 00:00:00, dtype: float64
#
# 2024-04-22: executing pending target
# NVDA     0.101137
# TSLA     0.000000
# AAPL     0.000000
# AMZN     0.114929
# MSFT     0.121409
# META     0.482805
# GOOGL    0.079719
# dtype: float64
# Current prices executed at:
# NVDA      87.690269
# TSLA     168.289993
# AAPL     167.773102
# AMZN     179.619995
# MSFT     401.091217
# META     440.682068
# GOOGL    170.660538
# Name: 2024-04-22 00:00:00, dtype: float64
#
# 2024-04-29: executing pending target
# NVDA     0.130535
# TSLA     0.000000
# AAPL     0.000000
# AMZN     0.125233
# MSFT     0.093179
# META     0.393879
# GOOGL    0.157174
# dtype: float64
# Current prices executed at:
# NVDA      88.743729
# TSLA     181.190002
# AAPL     181.726166
# AMZN     186.210007
# MSFT     401.426819
# META     449.300995
# GOOGL    165.985855
# Name: 2024-04-29 00:00:00, dtype: float64
#
# 2024-05-06: executing pending target
# NVDA     0.172593
# TSLA     0.000000
# AAPL     0.000000
# AMZN     0.159262
# MSFT     0.104089
# META     0.257291
# GOOGL    0.206764
# dtype: float64
# Current prices executed at:
# NVDA      89.832169
# TSLA     168.470001
# AAPL     181.399109
# AMZN     187.479996
# MSFT     409.402802
# META     473.398407
# GOOGL    167.385284
# Name: 2024-05-06 00:00:00, dtype: float64
#
# 2024-05-13: executing pending target
# NVDA     0.154316
# TSLA     0.000000
# AAPL     0.004252
# AMZN     0.160107
# MSFT     0.104223
# META     0.310101
# GOOGL    0.167002
# dtype: float64
# Current prices executed at:
# NVDA      92.431839
# TSLA     177.460007
# AAPL     188.412811
# AMZN     184.699997
# MSFT     414.802399
# META     469.133667
# GOOGL    174.739685
# Name: 2024-05-13 00:00:00, dtype: float64
#
# 2024-05-20: executing pending target
# NVDA     0.141775
# TSLA     0.000000
# AAPL     0.022792
# AMZN     0.130132
# MSFT     0.123373
# META     0.311571
# GOOGL    0.170357
# dtype: float64
# Current prices executed at:
# NVDA     106.414711
# TSLA     179.240005
# AAPL     188.521973
# AMZN     180.750000
# MSFT     425.390289
# META     475.406586
# GOOGL    173.677750
# Name: 2024-05-20 00:00:00, dtype: float64
#
# 2024-05-27: executing pending target
# NVDA     0.172775
# TSLA     0.000000
# AAPL     0.042868
# AMZN     0.093447
# MSFT     0.152695
# META     0.267101
# GOOGL    0.171113
# dtype: float64
# Current prices executed at:
# NVDA     109.577087
# TSLA     178.080002
# AAPL     190.774536
# AMZN     176.440002
# MSFT     410.526978
# META     464.083527
# GOOGL    171.206406
# Name: 2024-05-27 00:00:00, dtype: float64
#
# 2024-06-03: executing pending target
# NVDA     0.232161
# TSLA     0.000000
# AAPL     0.054051
# AMZN     0.066037
# MSFT     0.140422
# META     0.241873
# GOOGL    0.165456
# dtype: float64
# Current prices executed at:
# NVDA     120.826355
# TSLA     177.479996
# AAPL     195.378952
# AMZN     184.300003
# MSFT     419.150299
# META     490.059814
# GOOGL    173.151718
# Name: 2024-06-03 00:00:00, dtype: float64
#
# 2024-06-10: executing pending target
# NVDA     0.256525
# TSLA     0.000000
# AAPL     0.073651
# AMZN     0.067161
# MSFT     0.104727
# META     0.247532
# GOOGL    0.150404
# dtype: float64
# Current prices executed at:
# NVDA     131.812759
# TSLA     178.009995
# AAPL     210.859222
# AMZN     183.660004
# MSFT     437.662689
# META     501.193939
# GOOGL    175.464249
# Name: 2024-06-10 00:00:00, dtype: float64
#
# 2024-06-17: executing pending target
# NVDA     0.234822
# TSLA     0.000000
# AAPL     0.102395
# AMZN     0.062417
# MSFT     0.135197
# META     0.248624
# GOOGL    0.116545
# dtype: float64
# Current prices executed at:
# NVDA     126.515846
# TSLA     183.009995
# AAPL     205.897614
# AMZN     189.080002
# MSFT     444.792755
# META     492.357452
# GOOGL    178.487564
# Name: 2024-06-17 00:00:00, dtype: float64
#
# 2024-06-24: executing pending target
# NVDA     0.219822
# TSLA     0.000000
# AAPL     0.118516
# AMZN     0.062649
# MSFT     0.174069
# META     0.210819
# GOOGL    0.114125
# dtype: float64
# Current prices executed at:
# NVDA     123.487152
# TSLA     197.880005
# AAPL     209.003555
# AMZN     193.250000
# MSFT     441.994080
# META     501.751282
# GOOGL    180.991516
# Name: 2024-06-24 00:00:00, dtype: float64
#
# 2024-07-01: executing pending target
# NVDA     0.196610
# TSLA     0.008091
# AAPL     0.117208
# AMZN     0.081654
# MSFT     0.179520
# META     0.192432
# GOOGL    0.124486
# dtype: float64
# Current prices executed at:
# NVDA     125.776169
# TSLA     251.520004
# AAPL     224.602921
# AMZN     200.000000
# MSFT     462.375580
# META     537.266541
# GOOGL    189.387802
# Name: 2024-07-01 00:00:00, dtype: float64
#
# 2024-07-08: executing pending target
# NVDA     0.131979
# TSLA     0.129042
# AAPL     0.114712
# AMZN     0.073098
# MSFT     0.150340
# META     0.196879
# GOOGL    0.103950
# dtype: float64
# Current prices executed at:
# NVDA     129.184738
# TSLA     248.229996
# AAPL     228.770691
# AMZN     194.490005
# MSFT     448.520905
# META     496.427460
# GOOGL    183.892960
# Name: 2024-07-08 00:00:00, dtype: float64
#
# 2024-07-15: executing pending target
# NVDA     0.119894
# TSLA     0.199373
# AAPL     0.131990
# AMZN     0.063465
# MSFT     0.138122
# META     0.153271
# GOOGL    0.093885
# dtype: float64
# Current prices executed at:
# NVDA     117.879547
# TSLA     239.199997
# AAPL     222.588486
# AMZN     183.130005
# MSFT     432.263214
# META     474.455536
# GOOGL    176.530090
# Name: 2024-07-15 00:00:00, dtype: float64
#
# 2024-07-22: executing pending target
# NVDA     0.144069
# TSLA     0.260610
# AAPL     0.179964
# AMZN     0.045891
# MSFT     0.117675
# META     0.052772
# GOOGL    0.099019
# dtype: float64
# Current prices executed at:
# NVDA     113.011627
# TSLA     219.800003
# AAPL     216.287231
# AMZN     182.500000
# MSFT     420.554504
# META     463.419830
# GOOGL    165.937881
# Name: 2024-07-22 00:00:00, dtype: float64
#
# 2024-07-29: executing pending target
# NVDA     0.158627
# TSLA     0.319563
# AAPL     0.239889
# AMZN     0.021036
# MSFT     0.074327
# META     0.000000
# GOOGL    0.086558
# dtype: float64
# Current prices executed at:
# NVDA     107.224106
# TSLA     207.669998
# AAPL     218.172638
# AMZN     167.899994
# MSFT     403.960571
# META     485.749969
# GOOGL    165.600052
# Name: 2024-07-29 00:00:00, dtype: float64
#
# 2024-08-05: executing pending target
# NVDA     0.168286
# TSLA     0.320660
# AAPL     0.349349
# AMZN     0.000000
# MSFT     0.000000
# META     0.000000
# GOOGL    0.061705
# dtype: float64
# Current prices executed at:
# NVDA     104.705185
# TSLA     200.000000
# AAPL     214.580429
# AMZN     166.940002
# MSFT     401.517975
# META     515.234985
# GOOGL    162.629059
# Name: 2024-08-05 00:00:00, dtype: float64
#
# 2024-08-12: executing pending target
# NVDA     0.102829
# TSLA     0.201333
# AAPL     0.353912
# AMZN     0.000000
# MSFT     0.000000
# META     0.203844
# GOOGL    0.038081
# dtype: float64
# Current prices executed at:
# NVDA     124.526703
# TSLA     216.119995
# AAPL     224.315125
# AMZN     177.059998
# MSFT     413.829926
# META     524.837708
# GOOGL    161.923584
# Name: 2024-08-12 00:00:00, dtype: float64
#
# 2024-08-19: executing pending target
# NVDA     0.137642
# TSLA     0.174709
# AAPL     0.267507
# AMZN     0.000000
# MSFT     0.000000
# META     0.318403
# GOOGL    0.001740
# dtype: float64
# Current prices executed at:
# NVDA     129.314636
# TSLA     220.320007
# AAPL     225.359634
# AMZN     177.039993
# MSFT     412.911438
# META     525.414734
# GOOGL    164.566650
# Name: 2024-08-19 00:00:00, dtype: float64
#
# 2024-08-26: executing pending target
# NVDA     0.184550
# TSLA     0.205186
# AAPL     0.237497
# AMZN     0.000000
# MSFT     0.000000
# META     0.268584
# GOOGL    0.004183
# dtype: float64
# Current prices executed at:
# NVDA     119.318932
# TSLA     214.110001
# AAPL     227.505524
# AMZN     178.500000
# MSFT     413.258179
# META     518.757507
# GOOGL    162.340927
# Name: 2024-08-26 00:00:00, dtype: float64
#
# 2024-09-02: executing pending target
# NVDA     0.167923
# TSLA     0.213932
# AAPL     0.261664
# AMZN     0.000000
# MSFT     0.000000
# META     0.256481
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA     102.786011
# TSLA     210.729996
# AAPL     219.378922
# AMZN     171.389999
# MSFT     397.961853
# META     497.820557
# GOOGL    149.960159
# Name: 2024-09-02 00:00:00, dtype: float64
#
# 2024-09-09: executing pending target
# NVDA     0.076734
# TSLA     0.261774
# AAPL     0.350541
# AMZN     0.000000
# MSFT     0.000000
# META     0.210951
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA     119.049042
# TSLA     230.289993
# AAPL     221.047958
# AMZN     186.490005
# MSFT     426.583008
# META     522.051392
# GOOGL    156.458572
# Name: 2024-09-09 00:00:00, dtype: float64
#
# 2024-09-16: executing pending target
# NVDA     0.056338
# TSLA     0.346093
# AAPL     0.281102
# AMZN     0.000000
# MSFT     0.000000
# META     0.216468
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA     115.960297
# TSLA     238.250000
# AAPL     226.710754
# AMZN     191.600006
# MSFT     431.219421
# META     558.601562
# GOOGL    162.765274
# Name: 2024-09-16 00:00:00, dtype: float64
#
# 2024-09-23: executing pending target
# NVDA     0.067234
# TSLA     0.260084
# AAPL     0.159106
# AMZN     0.046008
# MSFT     0.062060
# META     0.305507
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA     121.358444
# TSLA     260.459991
# AAPL     226.303436
# AMZN     187.970001
# MSFT     424.036926
# META     565.120728
# GOOGL    163.123459
# Name: 2024-09-23 00:00:00, dtype: float64
#
# 2024-09-30: executing pending target
# NVDA     0.054899
# TSLA     0.277539
# AAPL     0.134111
# AMZN     0.039149
# MSFT     0.041305
# META     0.352996
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA     124.877235
# TSLA     250.080002
# AAPL     225.319901
# AMZN     186.509995
# MSFT     412.188232
# META     593.587891
# GOOGL    166.217789
# Name: 2024-09-30 00:00:00, dtype: float64
#
# 2024-10-07: executing pending target
# NVDA     0.070090
# TSLA     0.280963
# AAPL     0.113972
# AMZN     0.022490
# MSFT     0.000000
# META     0.412485
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA     134.753860
# TSLA     217.800003
# AAPL     226.065018
# AMZN     188.820007
# MSFT     412.445801
# META     587.621643
# GOOGL    162.417038
# Name: 2024-10-07 00:00:00, dtype: float64
#
# 2024-10-14: executing pending target
# NVDA     0.104494
# TSLA     0.173031
# AAPL     0.110697
# AMZN     0.024924
# MSFT     0.000000
# META     0.486853
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA     137.952759
# TSLA     220.699997
# AAPL     233.466370
# AMZN     188.990005
# MSFT     414.268707
# META     574.194763
# GOOGL    162.596130
# Name: 2024-10-14 00:00:00, dtype: float64
#
# 2024-10-21: executing pending target
# NVDA     0.151068
# TSLA     0.090026
# AAPL     0.138529
# AMZN     0.035814
# MSFT     0.000000
# META     0.484562
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA     141.491547
# TSLA     269.190002
# AAPL     229.899811
# AMZN     187.830002
# MSFT     424.165710
# META     570.987427
# GOOGL    164.436798
# Name: 2024-10-21 00:00:00, dtype: float64
#
# 2024-10-28: executing pending target
# NVDA     0.147255
# TSLA     0.215222
# AAPL     0.126740
# AMZN     0.029513
# MSFT     0.000000
# META     0.381270
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA     135.353653
# TSLA     248.979996
# AAPL     221.455276
# AMZN     197.929993
# MSFT     406.551178
# META     564.921387
# GOOGL    170.426437
# Name: 2024-10-28 00:00:00, dtype: float64
#
# 2024-11-04: executing pending target
# NVDA     0.131277
# TSLA     0.287721
# AAPL     0.081199
# AMZN     0.053057
# MSFT     0.000000
# META     0.346746
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA     147.579468
# TSLA     321.220001
# AAPL     225.478851
# AMZN     208.179993
# MSFT     418.607910
# META     587.013977
# GOOGL    177.450851
# Name: 2024-11-04 00:00:00, dtype: float64
#
# 2024-11-11: executing pending target
# NVDA     0.110850
# TSLA     0.336015
# AAPL     0.044352
# AMZN     0.088849
# MSFT     0.000000
# META     0.294779
# GOOGL    0.025153
# dtype: float64
# Current prices executed at:
# NVDA     141.931381
# TSLA     320.720001
# AAPL     223.777573
# AMZN     202.610001
# MSFT     411.138092
# META     551.893127
# GOOGL    171.620392
# Name: 2024-11-11 00:00:00, dtype: float64
#
# 2024-11-18: executing pending target
# NVDA     0.103972
# TSLA     0.433146
# AAPL     0.037635
# AMZN     0.086170
# MSFT     0.000000
# META     0.215130
# GOOGL    0.023948
# dtype: float64
# Current prices executed at:
# NVDA     141.901398
# TSLA     352.559998
# AAPL     228.621109
# AMZN     197.119995
# MSFT     413.119507
# META     556.933105
# GOOGL    163.929367
# Name: 2024-11-18 00:00:00, dtype: float64
#
# 2024-11-25: executing pending target
# NVDA     0.094859
# TSLA     0.539771
# AAPL     0.042332
# AMZN     0.068631
# MSFT     0.000000
# META     0.154407
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA     138.202682
# TSLA     345.160004
# AAPL     236.040588
# AMZN     207.889999
# MSFT     420.359100
# META     572.053223
# GOOGL    168.098251
# Name: 2024-11-25 00:00:00, dtype: float64
#
# 2024-12-02: executing pending target
# NVDA     0.071087
# TSLA     0.525877
# AAPL     0.059545
# AMZN     0.071598
# MSFT     0.000000
# META     0.171893
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA     142.391235
# TSLA     389.220001
# AAPL     241.520645
# AMZN     227.029999
# MSFT     440.321838
# META     621.308105
# GOOGL    173.829208
# Name: 2024-12-02 00:00:00, dtype: float64
#
# 2024-12-09: executing pending target
# NVDA     0.049589
# TSLA     0.431218
# AAPL     0.060400
# AMZN     0.099812
# MSFT     0.028948
# META     0.222395
# GOOGL    0.007638
# dtype: float64
# Current prices executed at:
# NVDA     134.213287
# TSLA     436.230011
# AAPL     246.781921
# AMZN     227.460007
# MSFT     443.994720
# META     617.901550
# GOOGL    188.863037
# Name: 2024-12-09 00:00:00, dtype: float64
#
# 2024-12-16: executing pending target
# NVDA     0.030026
# TSLA     0.422652
# AAPL     0.054678
# AMZN     0.096662
# MSFT     0.049939
# META     0.214556
# GOOGL    0.031487
# dtype: float64
# Current prices executed at:
# NVDA     134.663162
# TSLA     421.059998
# AAPL     253.107346
# AMZN     224.919998
# MSFT     433.402893
# META     582.940125
# GOOGL    190.663284
# Name: 2024-12-16 00:00:00, dtype: float64
#
# 2024-12-23: executing pending target
# NVDA     0.019370
# TSLA     0.461386
# AAPL     0.067389
# AMZN     0.094078
# MSFT     0.041244
# META     0.162195
# GOOGL    0.054338
# dtype: float64
# Current prices executed at:
# NVDA     136.972534
# TSLA     431.660004
# AAPL     254.201355
# AMZN     223.750000
# MSFT     427.377319
# META     597.924500
# GOOGL    192.007996
# Name: 2024-12-23 00:00:00, dtype: float64
#
# 2024-12-30: executing pending target
# NVDA     0.025091
# TSLA     0.476304
# AAPL     0.081206
# AMZN     0.094153
# MSFT     0.021465
# META     0.138623
# GOOGL    0.063158
# dtype: float64
# Current prices executed at:
# NVDA     144.430496
# TSLA     410.440002
# AAPL     242.037827
# AMZN     224.190002
# MSFT     420.249939
# META     602.729370
# GOOGL    191.041779
# Name: 2024-12-30 00:00:00, dtype: float64
#
# 2025-01-13: executing pending target
# NVDA     0.043154
# TSLA     0.440988
# AAPL     0.035892
# AMZN     0.097515
# MSFT     0.000000
# META     0.208285
# GOOGL    0.074166
# dtype: float64
# Current prices executed at:
# NVDA     137.672348
# TSLA     426.500000
# AAPL     228.730515
# AMZN     225.940002
# MSFT     425.888306
# META     610.843750
# GOOGL    195.235382
# Name: 2025-01-13 00:00:00, dtype: float64
#
# 2025-01-20: executing pending target
# NVDA     0.029464
# TSLA     0.457045
# AAPL     0.010553
# AMZN     0.099358
# MSFT     0.002494
# META     0.218126
# GOOGL    0.082960
# dtype: float64
# Current prices executed at:
# NVDA     142.580994
# TSLA     406.579987
# AAPL     221.569641
# AMZN     234.850006
# MSFT     440.808228
# META     645.454651
# GOOGL    199.428955
# Name: 2025-01-20 00:00:00, dtype: float64
#
# 2025-01-27: executing pending target
# NVDA     0.035422
# TSLA     0.400678
# AAPL     0.000000
# AMZN     0.108768
# MSFT     0.044928
# META     0.225844
# GOOGL    0.084360
# dtype: float64
# Current prices executed at:
# NVDA     120.037170
# TSLA     404.600006
# AAPL     234.717819
# AMZN     237.679993
# MSFT     412.020599
# META     687.013611
# GOOGL    203.224091
# Name: 2025-01-27 00:00:00, dtype: float64
#
# 2025-02-03: executing pending target
# NVDA     0.005463
# TSLA     0.337205
# AAPL     0.000000
# AMZN     0.119481
# MSFT     0.023603
# META     0.321582
# GOOGL    0.092666
# dtype: float64
# Current prices executed at:
# NVDA     129.804474
# TSLA     361.619995
# AAPL     226.393295
# AMZN     229.149994
# MSFT     406.749481
# META     712.273987
# GOOGL    184.616959
# Name: 2025-02-03 00:00:00, dtype: float64
#
# 2025-02-10: executing pending target
# NVDA     0.000000
# TSLA     0.270149
# AAPL     0.002243
# AMZN     0.114609
# MSFT     0.000000
# META     0.440575
# GOOGL    0.072425
# dtype: float64
# Current prices executed at:
# NVDA     138.812027
# TSLA     355.839996
# AAPL     243.271072
# AMZN     228.679993
# MSFT     405.439148
# META     734.354309
# GOOGL    184.507385
# Name: 2025-02-10 00:00:00, dtype: float64
#
# 2025-02-17: executing pending target
# NVDA     0.011752
# TSLA     0.181647
# AAPL     0.016040
# AMZN     0.100774
# MSFT     0.000000
# META     0.549420
# GOOGL    0.040368
# dtype: float64
# Current prices executed at:
# NVDA     134.393234
# TSLA     337.799988
# AAPL     244.484421
# AMZN     216.580002
# MSFT     405.220734
# META     681.401306
# GOOGL    178.959106
# Name: 2025-02-17 00:00:00, dtype: float64
#
# 2025-02-24: executing pending target
# NVDA     0.020366
# TSLA     0.139294
# AAPL     0.058556
# AMZN     0.083533
# MSFT     0.000000
# META     0.565691
# GOOGL    0.032561
# dtype: float64
# Current prices executed at:
# NVDA     124.885841
# TSLA     292.980011
# AAPL     240.790527
# AMZN     212.279999
# MSFT     394.873108
# META     666.099609
# GOOGL    169.615707
# Name: 2025-02-24 00:00:00, dtype: float64
#
# 2025-03-03: executing pending target
# NVDA     0.000000
# TSLA     0.000000
# AAPL     0.096836
# AMZN     0.072808
# MSFT     0.000000
# META     0.730356
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA     112.659187
# TSLA     262.670013
# AAPL     238.032562
# AMZN     199.250000
# MSFT     391.212738
# META     623.693298
# GOOGL    173.181732
# Name: 2025-03-03 00:00:00, dtype: float64
#
# 2025-03-10: executing pending target
# NVDA     0.000000
# TSLA     0.000000
# AAPL     0.114963
# AMZN     0.000000
# MSFT     0.000000
# META     0.785037
# GOOGL    0.000000
# dtype: float64
# Current prices executed at:
# NVDA     121.636726
# TSLA     249.979996
# AAPL     212.563553
# AMZN     197.949997
# MSFT     386.488068
# META     605.690002
# GOOGL    164.844391
# Name: 2025-03-10 00:00:00, dtype: float64
#
# 2025-03-17: executing pending target
# NVDA     0.0
# TSLA     0.0
# AAPL     0.0
# AMZN     0.0
# MSFT     0.0
# META     0.9
# GOOGL    0.0
# dtype: float64
# Current prices executed at:
# NVDA     117.678635
# TSLA     248.710007
# AAPL     217.322830
# AMZN     196.210007
# MSFT     389.173676
# META     594.904541
# GOOGL    163.538376
# Name: 2025-03-17 00:00:00, dtype: float64
#
# 2025-03-24: executing pending target
# NVDA     0.0
# TSLA     0.0
# AAPL     0.0
# AMZN     0.0
# MSFT     0.0
# META     0.0
# GOOGL    0.0
# dtype: float64
# Current prices executed at:
# NVDA     109.650101
# TSLA     263.549988
# AAPL     216.954422
# AMZN     192.720001
# MSFT     376.780090
# META     575.438599
# GOOGL    153.904968
# Name: 2025-03-24 00:00:00, dtype: float64
#
# Total Number of Trades Made (including Portfolio Rebalances),  103

# %%
# Creating the benchmark strategy - a buy and hold all stocks strategy 

backtest.portfolio_returns
backtest.data[tradable_assets]

# 100000 / len_assets 
# take 0.05 commission for the whole trade 
# recalculate 

results = VisualiseBacktestResults(backtest)
benchmark_returns = backtest.data[tradable_assets].pct_change().mean(axis=1).dropna()
alpha = results.benchmark(benchmark_returns=benchmark_returns, riskfree=0.0)
# Out:
# Constant term of the regression: -0.0014636292053056947
#
# NB: The alpha value is given in the constant term.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     370.4
# Date:                Sun, 15 Feb 2026   Prob (F-statistic):           1.30e-37
# Time:                        18:50:40   Log-Likelihood:                 304.46
# No. Observations:                 116   AIC:                            -604.9
# Df Residuals:                     114   BIC:                            -599.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0015      0.002     -0.857      0.393      -0.005       0.002
# 0              0.9214      0.048     19.246      0.000       0.827       1.016
# ==============================================================================
# Omnibus:                       17.251   Durbin-Watson:                   1.831
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.104
# Skew:                          -0.330   Prob(JB):                     1.46e-13
# Kurtosis:                       6.434   Cond. No.                         29.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.hlines(y=0.9, xmin=backtest.position_history.index[0],
          xmax=backtest.position_history.index[-1], 
          linestyle="--",
            color="red", 
            label="Max Allowed Position in Assets ")

backtest.position_history.plot(ax=ax)

plt.title("Relative Position over Time for all Stocks", fontsize=15)
ax.legend()
plt.show()
# Out:
# c:\Users\trund\QRT\venv\lib\site-packages\pandas\plotting\_matplotlib\core.py:981: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   return ax.plot(*args, **kwds)

# %%
results.performance_dashboard()
